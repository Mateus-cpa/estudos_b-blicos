# %% [markdown]
# <a href="https://colab.research.google.com/github/Mateus-cpa/estudos_b-blicos/blob/main/rpg/rpg_biblico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # O sistema

# %% [markdown]
# # História
# ##Regra geral
# Existem três níveis de disponibilidade por bloco:
#
# - Livre: combina naturalmente com o período.
#
# - Limitado: existe, mas com restrição narrativa ou social.
#
# - Inaplicável: não faz sentido histórico ou ainda não existe no cenário.
#
# Para a mesa, isso evita discussões e também protege a identidade de cada período. A base histórica das tribos, do sistema tribal e da ausência de rei e exército profissional é especialmente importante para separar os períodos de juízes, monarquia e exílio.
#
# ## Restrições por povo
# Como regra geral, eu também limitaria os povos conforme a linha histórica:
#
# - Egípcios: livres em blocos 1 a 3; limitados depois como potência externa ou lembrança política.
#
# - Filisteus: fortes do bloco 5 ao 7; antes disso podem ser raros ou inexistentes como potência regional.
#
# - Sidônios e cananeus: mais presentes do bloco 2 ao 7, especialmente comércio, litoral e conflito religioso.
#
# - Tribo de Israel: começa nas famílias patriarcais, se consolida no êxodo e explode em variedade nos blocos 5 a 9.
#
# - Rúben, Simeão, Levi, Judá, Dã, Naftali, Gade, Aser, Issacar, Zebulom, Efraim, Manassés, Benjamim: aplicáveis principalmente a partir da conquista; Levi fica muito forte quando o culto e o tabernáculo entram em cena.
#
# ## Restrições por treinamento
# Em termos de treinamento, eu faria assim:
#
# - Pastor nômade: forte nos blocos 1 a 4; depois vira periférico.
#
# - Artesão: presente em todos, mas ganha peso em monarquia, exílio e retorno.
#
# - Guerreiro: forte de 3 a 7; mais limitado em 1, 2, 8 e 9.
#
# - Guardião: forte de 4 a 9; quase ausente em 1.
#
# - Profeta: limitado no começo, fortíssimo de 4 a 9.
#
# - Levita/Sacerdote: praticamente inexistentes antes do êxodo; centrais de 4 em diante.
#
# - Conselheiro/Mensageiro: bons em todos os blocos, mas mudam de tom conforme a estrutura política.

# %% [markdown]
# ## 1} Origem da humanidade
# Este bloco cobre criação, queda, Caim e Abel, Noé e o Dilúvio, além da dispersão dos povos. Para o jogo, ele funciona como mito fundacional, explicando pecado, violência, pacto, julgamento e recomeço. É ótimo para introduções teológicas, mas ruim para campanha longa, porque há poucos personagens recorrentes e pouca geopolítica estável.
#
# Neste bloco, quase nenhum povo histórico em sentido estrito deve ser jogável como “nação organizada”; o foco é em grupos primordiais, linhagens e famílias. Treinamentos espirituais como profeta, sacerdote e conselheiro podem aparecer só como arquétipos ou figuras excepcionais, não como estruturas consolidadas. Povos como egípcios, filisteus ou tribos israelitas ainda não funcionam como blocos políticos completos.
#
# Livre: conselheiro, pastor nômade, artesão.
#
# Limitado: guerreiro, mensageiro, profeta.
#
# Inaplicável: levita, sacerdote, guardião.

# %% [markdown]
# ![1000002883.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![1000002884.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2} Patriarcas
# Aqui entram Abraão, Isaque, Jacó e José, com a formação das famílias tribais e a ida ao Egito. Esse período é excelente para campanhas de viagem, alianças, conflitos familiares e promessas divinas, porque tudo ainda está em formação. É um bloco muito aplicável ao jogo, especialmente se você quiser jogar “origem de povo” e “vocação de família”.
#
# Aqui os patriarcas, clãs e famílias são o centro, então povos e treinamentos ligados a linhagem e jornada funcionam bem. Pastor nômade, mensageiro, artesão, conselheiro e guerreiro se encaixam naturalmente. Já funções como levita e sacerdote ainda não existem como instituição; podem aparecer apenas em forma embrionária ou ancestral.
#
# Livre: pastor nômade, mensageiro, conselheiro, artesão.
#
# Limitado: guerreiro, profeta, guardião.
#
# Inaplicável: levita, sacerdote, treinamentos de templo.

# %% [markdown]
# ## 3} Egito e opressão
# Este bloco cobre o crescimento dos hebreus no Egito, a mudança política, a escravidão e a pressão imperial. Em termos de cenário, ele é forte para drama social, perseguição, trabalho forçado e resistência religiosa. Serve bem para aventuras de fuga, sobrevivência e conspiração, mas menos para exploração aberta de mapa.
#
# Aqui os egípcios entram com força como poder dominante, e os hebreus aparecem como povo submetido. Artesão, conselheiro, mensageiro e guardião funcionam bem no lado egípcio; do lado hebreu, pastor nômade perde força urbana, mas ainda pode existir em regiões de margem ou lembrança tribal. Sacerdote e levita só fazem sentido do lado egípcio se forem religiosos locais, não como função israelita formal.
#
# Livre: artesão, conselheiro, mensageiro, guardião.
#
# Limitado: pastor nômade, guerreiro, profeta.
#
# Inaplicável: levita, sacerdote.

# %% [markdown]
# ## 4} Êxodo e deserto
# Aqui entram Moisés, as pragas, a saída do Egito, o Sinai, a aliança e a caminhada no deserto. Esse é um dos melhores blocos para o seu sistema, porque combina escassez, pressão, fé, risco, liderança e milagres narrativos. Ele é muito aplicável tanto para campanha curta quanto para uma fase inteira do jogo.
#
# Esse bloco é ideal para pastor nômade, mensageiro, conselheiro, guardião, profeta e guerreiro. A vida em marcha favorece sobrevivência, vigilância, liderança espiritual e conflitos com povos hostis. Sacerdote e levita já começam a ficar plenamente aplicáveis, porque o culto e o tabernáculo ganham centralidade.
#
# Livre: pastor nômade, mensageiro, guardião, profeta, levita, sacerdote.
#
# Limitado: artesão, guerreiro, conselheiro.
#
# Inaplicável: treinamento urbano de corte ou de reino consolidado.

# %% [markdown]
# ## 5} Conquista e Juízes
# Este bloco cobre Josué, a entrada em Canaã, a divisão das terras e o período dos juízes. É um período ideal para campanhas de fronteira, guerra irregular, ambiguidade moral e assentamento de povos. Aqui o jogo pode ficar mais tático e territorial, com aldeias, conflitos locais e alianças instáveis.
#
# Aqui o sistema tribal está em plena forma, sem rei e sem exército profissional, com juízes atuando como chefes de guerra e mediadores da unidade. Guerreiro, guardião, mensageiro, profeta, pastor nômade e conselheiro ficam muito fortes. Levita e sacerdote seguem plenamente válidos, mas com influência distribuída pelas tribos e cidades de refúgio.
#
# Livre: guerreiro, guardião, mensageiro, profeta, levita, sacerdote.
#
# Limitado: artesão, conselheiro, pastor nômade.
#
# Inaplicável: cargos de palácio, burocracia real, diplomacia estatal ampla.

# %% [markdown]
# ## 6} Monarquia unida
# Aqui estão Saul, Davi e Salomão, com a centralização do poder, a conquista política, a formação da capital e o templo. Esse bloco é ótimo para intriga de corte, guerras de expansão, sucessão e construção de identidade nacional. É um período muito aplicável porque permite campanha épica, política e espiritual ao mesmo tempo.
#
# Aqui Judá, Benjamim, Efraim e as demais tribos já convivem sob centralização política, então quase todos os povos citados no livro podem aparecer com mais facilidade, especialmente os vizinhos e inimigos clássicos. Conselheiro, guardião, mensageiro, guerreiro, artesão, sacerdote e levita ficam fortes, e profeta passa a ter peso político. Pastor nômade continua possível, mas agora mais periférico ou regional.
#
# Livre: conselheiro, mensageiro, artesão, guardião, guerreiro, sacerdote, levita, profeta.
#
# Limitado: pastor nômade, sobrevivência tribal clássica.
#
# Inaplicável: ausência de estrutura real ou capital central.

# %% [markdown]
# ## 7} Reino dividido
# Depois de Salomão, o reino se parte em Israel ao norte e Judá ao sul, com dinastias, profetas e crises internas. Este é um bloco riquíssimo para campanha, porque mistura guerra civil, idolatria, conflitos de legitimidade e intervenção profética. Ele também é um dos melhores para o seu sistema, já que os treinamentos e povos podem influenciar fortemente o jogo social e espiritual.
#
# Esse é o grande período para conflitos entre Judá, Efraim, Benjamim e os povos vizinhos, com profetas atuando como voz de confronto e povos como egípcios, filisteus, sidônios e cananeus aparecendo com intensidade. Profeta, conselheiro, mensageiro, sacerdote, levita, guerreiro e guardião são muito naturais. Artesão continua útil, mas mais ligado a cidades, palácios, fortificações e culto.
#
# Livre: profeta, conselheiro, mensageiro, sacerdote, levita, guerreiro, guardião.
#
# Limitado: pastor nômade, artesão de fronteira.
#
# Inaplicável: sistema tribal sem reis, unidade política total.

# %% [markdown]
# ## 8} Período de transição persa
# Se você quiser um nono bloco opcional, vale separar o retorno do exílio e a reorganização sob a Pérsia. Aqui entram reconstrução do templo, restauração comunitária e tensões entre pureza, lei e sobrevivência política. Esse período é ótimo para campanhas de reforma e reconstrução, e conversa bem com funções como sacerdote, escriba, profeta e conselheiro.
#
# Se você manter esse bloco separado, ele favorece reconstrução, administração, escrita, ensino e restauração do culto. Conselheiro, artesão, mensageiro, sacerdote, levita e profeta dominam claramente, enquanto guerreiro aparece mais como defesa local ou proteção de obras. Esse é um ótimo período para personagens voltados à lei, memória e organização comunitária.
#
# Livre: conselheiro, artesão, mensageiro, sacerdote, levita, profeta.
#
# Limitado: guerreiro, guardião.
#
# Inaplicável: império próprio israelita soberano.

# %% [markdown]
# ## 9} Exílio e retorno
# Este bloco cobre a queda de Samaria, a queda de Jerusalém, o cativeiro babilônico e o retorno sob domínio estrangeiro. Para a mesa, ele funciona muito bem como cenário de perda, memória, reconstrução e fidelidade em terra estranha. É um bloco excelente para histórias mais maduras, com foco em restauração, identidade e resistência cultural.
#
# Neste bloco, o cenário muda para sobrevivência cultural, identidade, reconstrução e fidelidade em terra estrangeira ou em retorno precário. Sacerdote, levita, profeta, conselheiro, artesão e mensageiro são os treinamentos mais fortes; guerreiro fica mais limitado, porque o foco deixa de ser conquista direta. Povos dominantes como babilônios ou persas podem ser tratados como pano de fundo político, e não como campo de guerra constante.
#
# Livre: sacerdote, levita, profeta, conselheiro, artesão, mensageiro.
#
# Limitado: guerreiro, guardião, diplomacia com estrangeiros.
#
# Inaplicável: conquista territorial ampla, monarquia estável plena.

# %% [markdown]
# ## 10} Domínio Romano e início da Igreja
# Nesta época o cenário ganha novas tensões políticas e religiosas, porque a relação deixa de ser só entre Israel, reinos vizinhos e exílios, e passa a envolver Roma, autoridade local, sinagoga, templo e comunidades cristãs em formação �. Isso também permite campanhas mais urbanas, missionárias e de conflito ideológico, sem perder o pano de fundo bíblico.

# %% [markdown]
# # Criação do Personagem
#
# Neste jogo, cada personagem é alguém chamado a agir com coragem, fidelidade e obediência em meio a desafios reais. A criação não serve só para preencher números: ela define origem, vocação, formação e estilo de contribuição na história.
#
# Todos os dados são preenchidos na [ficha](https://docs.google.com/spreadsheets/d/1ae7bsRV-e6t5E_vWyp-soIFXHRhpLkugWp5rB8B_9-A/edit?usp=sharing).
#
# ## Como funciona
# A criação de personagem é feita em camadas. Primeiro você escolhe o povo, depois o treinamento, e então distribui os atributos; por fim, aplica as vantagens recebidas e registra os traços narrativos do personagem.
#
# A lógica do sistema é simples: o povo concede vantagens em perícias, enquanto o treinamento melhora atributos; quando o treinamento eleva um atributo ao nível 2 ou 5, o personagem pode ganhar uma vantagem adicional em uma perícia compatível.
#
# ## Regra de escolha
# Siga esta ordem:
#
# 1. Escolha o povo.
#
# 2. Escolha o treinamento.
#
# 3. Distribua os atributos.
#
# 4. Aplique as vantagens do povo.
#
# 5. Aplique os bônus do treinamento aos atributos.
#
# 6. Se algum atributo do treinamento atingir nível 2 ou 5, escolha 1 perícia compatível para receber vantagem.
#
# 7. Anote marcas de fé, vocação e detalhes narrativos.
#
# Essa ordem ajuda a manter o personagem coerente com o cenário. Primeiro vem a identidade cultural; depois, a formação prática e espiritual.
#
# ## Exemplos
# **Exemplo 1**: personagem do povo Levi com treinamento Levita
# O personagem recebe vantagens em perícias ligadas ao serviço sagrado, como Cura, Vontade, Teologia ou Performance, e o treinamento reforça atributos apropriados para culto, serviço e disciplina. Se o treinamento elevar Sabedoria ao nível 2 ou 5, ele pode ganhar vantagem em uma perícia como Cura ou Intuição.
#
# **Exemplo 2**: personagem do povo Jud com treinamento Guerreiro
# Esse personagem tende a receber vantagens em Liderança, Diplomacia ou Luta por causa do povo, enquanto o treinamento fortalece atributos ligados à ação direta e à firmeza. Se o atributo do treinamento atingir um marco, ele pode ganhar vantagem em Luta ou Resistência, dependendo do foco da ficha.
#
# **Exemplo 3**: personagem do povo Aser com treinamento Artesão
# Aqui o personagem combina vantagens em Ofício, Trabalho ou Sobrevivência com um treinamento que melhora atributos ligados à criação, reparo e execução prática. Quando atinge os marcos do treinamento, pode receber uma vantagem adicional em Ofício ou Trabalho.
#
# | Etapa             | O que define                           | O que concede                                                                                        |
# | ----------------- | -------------------------------------- | ---------------------------------------------------------------------------------------------------- |
# | Povo              | Origem, tradição e papel social        | Vantagens em perícias coerentes com a identidade do povo rpg_biblico.ipynb.txt                       |
# | Treinamento       | Formação, disciplina e vocação prática | Melhoria de atributos e, em marcos específicos, vantagem em perícia compatível rpg_biblico.ipynb.txt |
# | Atributos         | Talento natural do personagem          | Base para perícias e progressão do treinamento rpg_biblico.ipynb.txt                                 |
# | Marcas narrativas | Fé, compromisso e vocação              | Identidade dramática e ligação com a história rpg_biblico.ipynb.txt                                  |

# %% [markdown]
# ## Vantagens e desvantagens por povo
#
# | Povo               | Vantagem(es)                                                                                                                                                      | Desvantagem de perícia                                      |
# | ------------------ | ----------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------- |
# | Egípcios           | Civilização do Nilo: vantagem em Ofício e História; Poder sacerdotal: vantagem em Teologia e rituais divinos                                | Diplomacia com povos escravizados ou hostis.                |
# | Filisteus          | Guerreiros do mar: vantagem em Luta em terreno costeiro ou planície; Tecnologia de ferro: vantagem em Ofício com armas e armaduras          | Diplomacia com povos nativos de Cana.                       |
# | Sidônios           | Senhores do mar: vantagem em Diplomacia e Comércio em portos; Artesãos da madeira: vantagem em Ofício com madeira e construção naval rpg_biblico.ipynb.txt        | Vontade contra suborno ou ganância.                         |
# | Rúben              | Primogênito: vantagem em Liderança dentre as tribos; Pastores do deserto: vantagem em Sobrevivência                                        | Vontade contra tentações de poder.                          |
# | Simeão             | Guerreiros violentos: vantagem em Luta contra inimigos numerosos; Justiça implacável: vantagem em Liderança                                 | Intuição para perceber armadilhas emocionais.               |
# | Levi               | Tribo sacerdotal: vantagem em Performance e Cura; Unção sagrada: vantagem em Vontade para situações espirituais                             | Trabalho e Ofício fora das funções do templo.               |
# | Judá               | Liderança real: vantagem em Liderança e Diplomacia com outras tribos                                               | Furtividade quando em grupo.                                |
# | Dã                 | Juízes e sentinelas: vantagem em Percepção e Intuição; Guerreiros astutos: vantagem em Furtividade em emboscadas   | Sobrevivência fora de Dã.     |
# | Naftali            | Mensageiros ágeis: vantagem em Acrobacia e Performance                                                                                    | Resistência contra invases ou pressão prolongada.           |
# | Gade               | Guerreiros da fronteira: vantagem em Arquearia e Resistência; Defensores de Gileade: vantagem em Luta em terreno montanhoso                | Diplomacia com povos fora de sua região.                    |
# | Aser               | Artesãos e agricultores: vantagem em Ofício e Sobrevivência; Riqueza da costa: vantagem em Trabalho em comércio                       | Furtividade quando carregando bens.                         |
# | Issacar            | Transportadores: vantagem em Trabalho e Resistência; Agricultores abençoados: vantagem em Sobrevivência       | Acrobacia e movimentos rápidos.                             |
# | Zebulom            | Comerciantes do mar: vantagem em Diplomacia e Intuição; Porto seguro: vantagem em Trabalho no mar/Navegação e comércio marítimo             | Sobrevivência longe de rotas comerciais.                    |
# | Efraim             | Fertilidade e prosperidade: vantagem em História e Teologia; Liderança no norte: vantagem em Liderança entre tribos do norte                 | Liderança sobre Judá e Benjamim.                            |
# | Manassés           | Guerreiros e líderes: vantagem em Luta e Liderança; Terra dobrada: vantagem em Sobrevivência em territórios próprios                        | Percepção para notar ameaças em fronteiras divididas.       |
# | Benjamim           | Guerreiros leais: vantagem em Luta quando defendendo aliados; Lobo feroz: vantagem em Liderança em combate                              | Diplomacia após conflitos.                                  |
# | Hebreus pré-Israel | F inabalável: vantagem em Vontade contra medo, tentação ou maldições; Resiliência do deserto: vantagem em Sobrevivência em ambientes áridos | Diplomacia com egípcios e alguns cananeus hostis.           |
# | Amoritas           | Trabalho, Ofício, Luta de montanha                                                                                                        | Diplomacia com nômades.                                     |
# | Heteus             | Ofício de ferro, Diplomacia com reinos                                                                                                       | Sobrevivência longe de cidades.                             |
# | Jebuseus           | Furtividade, Percepção urbano, Vontade de cerco                                                                                          | Diplomacia com desertoplâncie.                              |
# | Heveus             | Diplomacia, Intuição, Sobrevivência da paz                                                                                                | Luta ao iniciar combate.                                    |
# | Girgaseus          | Sobrevivência, História, Teologia de Cana                                                                                                   | Liderança fora da região.                                   |
# | Ferezeus           | Ofício, Sobrevivência, Liderança de aldeia                                                                                                 | Vontade contra cerco.                                       |
# | Midianitas         | Sobrevivência, Arquearia, Diplomacia de rotas                                                                                            | Ofício de oficina fixa.                                     |
# | Amalequitas        | Luta, Resistência, Furtividade no deserto                                                                                                 | Diplomacia com hebreus.                                     |
# | Edomitas           | Luta, Sobrevivência, Intuição                                                                                                           | Diplomacia com hebreus.                                     |
# | Ismaelitas         | Diplomacia, Sobrevivência, Arquearia no deserto                                                                                        | Ofício urbano e Diplomacia cortesã.                         |
# | Moabitas           | Ofício, Sobrevivência, Diplomacia de fora                                                                                               | Vontade contra maldições.                                   |
# | Amonitas           | Percepção, Vontade, Teologia do próprio culto                                                                                              | Diplomacia com estrangeiros.                                |
# | Cananeus           | O arquivo não fixa vantagens únicas aqui, mas os usa como povos da terra e das cidades                                                   | Diplomacia com hebreus, por tensão territorial e religiosa. |

# %% [markdown]
# ## Atributos
#
# Todo personagem possui seis atributos básicos: Força (FOR), Agilidade (AGI), Vigor (VGR), Intelecto (INT), Sabedoria (SAB) e Presença (PRS). Esses atributos representam os qualificações naturais do personagem e determinam sua eficiência em diferentes tipos de ação.
#
# Todos personagens começam com 1 de cada atributo.
#
# Ao criar um personagem, distribua os valores das habilidades conforme as regras da campanha. Depois disso, cada habilidade gera efeitos diretos sobre as perícias relacionadas.
#
# | Atributo | Nome | Favorecimento | Perícias | Referências | Especial |
# | -- | -- | -- | -- | -- | -- |
# |FOR|Força | ações de combate físico e esforço corporal| Escalar, Luta, Trabalho | | Levantar 40 kg + 10 por FOR|
# |AGI|   Agilidade | precisão, movimento e discrição | Arquearia, Furtividade, Acrobacia| | Nv3 = -1 dano, Nv5 = -2 dano|
# |VGR|   Vigor | resistência, fôlego e sobrevivência física | Resistência, Sobrevivência, Cura| | PV = (VGR + Nível) x 2|
# |INT|   Intelecto | conhecimento, técnica e raciocínio | Teologia, História, Ofício| PV 12:1 | 1 ofício por INT|
# |SAB| Sabedoria | percepção, discernimento e firmeza interior | Percepção, Intuição, Vontade | Pv 2:1-6 | Iniciativa ativa|
# |PRS| Presença | influência, liderança e expressão | Diplomacia, Liderança, Performance| | Nv3 = Comandar 100; Nv4 = Comandar 1000; Nv5 = Comandar povo|
#
#
# ### Valores altos de atributos
#
# Cada atributo pode variar de 1 a 5:
# Ao atingir o **nível 2** de qualquer atributo, permite selecionar mais uma perícia associada a ele. Mais 1 períca pode ser alcançada ao atingir o **nível 5**.

# %% [markdown]
# ## Regra de Vantagem por Atributo
# Cada personagem recebe uma vantagem em perícia para cada ponto de modificador de atributo positivo.
# Essa vantagem deve ser aplicada em uma perícia coerente com o atributo correspondente.
#
# Exemplo:
#
# - Um personagem com AGI alta pode receber vantagem em Arquearia, Furtividade ou Acrobacia.
#
# - Um personagem com INT alta pode receber vantagem em Teologia, História ou Ofício.
#
# - Um personagem com SAB alta pode receber vantagem em Percepção, Intuição ou Vontade.
#
# Se o personagem tiver modificadores positivos em mais de uma habilidade, ele recebe vantagens adicionais, sempre respeitando a coerência temática.

# %% [markdown]
# ## Escolha de Perícias na Criação
# Registre tudo na ficha conforme
#
# Isso faz com que o personagem seja definido não apenas por números, mas por perfil de vocação.

# %% [markdown]
# # Progressão
#
# > ⁵ O sábio ouvirá e crescerá em conhecimento, e o entendido adquirirá sábios conselhos;
# ⁶ Para entender os provérbios e sua interpretação; as palavras dos sábios e as suas proposições.
# ⁷ O temor do Senhor é o princípio do conhecimento; os loucos desprezam a sabedoria e a instrução. (Provérbios 1:5-7, ACF)
#
# Quanto o narrador indicar, os jogadores poderão melhorar seu personagem através da progressão. Em cada nível, o jogadpr poderá melhorar conforme
#
# | Nível | Modificador de dados | Atributo | Talento |
# | -- | -- | -- | -- |
# | 2 | | | Talento Neófito |
# | 3 | | + Atributo |
# | 4 | + 1 dado de comum | |
# | 5 | | | Talento Obreiro |
# | 6 | + 1 dado de fé | |Especialização  |
# | 7 | | + Atributo |
# | 8 | +1 dado comum | |
# | 9 | | + Atributo |
# | 10 | +1 dado de fé | | Talento Ancião |
#
#
# Com o avanço da história, o personagem ganha mais dados de classe nas rolagens. Isso faz o personagem crescer em presença dramática, não apenas em força matemática.
#
# - no início: 1 dado de classe em situações apropriadas;
#
# - depois: 2 dados de classe;
#
# - mais tarde: 3 dados de classe;
#
# - raramente: 4 dados de classe em momentos decisivos.
#
# Isso deixa o jogo cada vez mais épico sem quebrar a simplicidade.

# %% [markdown]
# ## Grupos sacerdotais
# Aqui vale incluir facções com peso real de jogo:
#
# - Fariseus, como grupo de interpretação rigorosa da Lei e da tradição.
# - Saduceus, ligados à elite sacerdotal e ao Templo.
# - Essênios, como corrente de separação e pureza comunitária.
# - Zelotes, como resistência política e insurreição.
# - Herodianos, quando você quiser trazer poder colaboracionista.
# - Igreja primitiva, como comunidades domésticas, missionárias e perseguidas �.
#
# Um sacerdote com níveis mais elevados escolhe também uma posição social, religiosa e política.

# %% [markdown]
# ## Levitas e sacerdotes
#
# Sobre levitas e sacerdotes, eu separaria “ordem de serviço” de “grupo de acesso”. Nem todo levita seria sacerdote, e nem todo personagem com função religiosa teria o mesmo nível de acesso ao Templo, ao ritual ou ao ensino formal. Isso permite criar condições especiais de acesso: alguém pode ser levita com funções auxiliares, sacerdote com prerrogativas litúrgicas, ou um não-levita atuando como escriba, mestre ou pregador em contexto sinagogal

# %% [markdown]
# ## Talentos
# são divididos em 3 categorias:
# - Neófito = competência básica, útil, ainda localizada.
#
# - Obreiro = domínio consistente, confiável em cena.
#
# - Ancião = autoridade narrativa, efeito amplo e decisivo.
#
# Isso está bom porque não só aumenta número; aumenta alcance e impacto.
# ### Conselheiro
# - Neófito: Palavras certas, Escuta prudente.
# - Obreiro: Leitura de conflito, Conselho oportuno.
# - Ancião: Sabedoria de tribunal, Paz restauradora.
# ### Artesão
# - Neófito: Mãos hábeis, Improviso útil.
# - Obreiro: Reparo rápido, Obra confiável.
# - Ancião: Trabalho exemplar, Solução duradoura.
# ### Guerreiro
# - Neófito: Golpe firme, Coragem em combate.
# - Obreiro: Defesa tática, Pressão constante.
# - Ancião: Virada da batalha, Determinação implacável.
# ### Guardião
# - Neófito: Postura vigilante, Bloqueio simples.
# - Obreiro: Proteção de aliado, Controle de espaço.
# - Ancião: Escudo do grupo, Guarda incansável.
# ### Levita
# - Neófito: Reverência, Ordem do culto.
# - Obreiro: Serviço do santuário, Condução litúrgica.
# - Ancião: Atmosfera santa, Restauração do ambiente.
# ### Mensageiro
# - Neófito: Caminho seguro, Entrega discreta.
# - Obreiro: Deslocamento ágil, Informação exata.
# - Ancião: Mensagem decisiva, Chegada no tempo certo.
# ### Pastor nômade
# - Neófito: Leitura de trilha, Provisão simples.
# - Obreiro: Rota segura, Cuidado do rebanho.
# - Ancião: Travessia guiada, Abrigo em tempo hostil.
# ### Profeta
# - Neófito: Intuição da raiz, Palavra inicial.
# - Obreiro: Confronto da verdade, Aviso claro.
# - Ancião: Declaração que muda a cena, Direção espiritual coletiva.
# ### Sacerdote
# - Neófito: Intercessão breve, Purificação menor.
# - Obreiro: Rito correto, Mediação estável.
# - Ancião: Restauração ampla, Reconciliação sagrada

# %% [markdown]
# # Povos
#
# | Povo/Tribo | Região Principal          | Vantagem Chave               | Desvantagem Chave      |
# | ---------- | ------------------------- | ---------------------------- | ---------------------- |
# | Egípcios   | Vale do Nilo              | Civilização, Sacerdócio      | Arrogância Imperial    |
# | Filisteus  | Costa sul de Canaã        | Guerreiros do mar, Ferro     | Invasores estrangeiros |
# | Sidônios   | Costa do Líbano           | Comércio, Navegação          | Ganância               |
# | Rúben      | Leste do Jordão (sul)     | Primogênito, Pastores        | Instabilidade moral    |
# | Simeão     | Sul de Judá               | Guerreiros violentos         | Fúria cega             |
# | Levi       | Espalhados (48 cidades)   | Sacerdotal, Teologia         | Sem terra              |
# | Judá       | Sul de Canaã (montanhas)  | Liderança real               | Alvo de inveja         |
# | Dã         | Norte de Canaã (Lais)     | Percepção, Furtividade       | Terra distante         |
# | Naftali    | Galileia, vale de Jezreel | Agilidade, Performance       | Fronteira exposta      |
# | Gade       | Leste do Jordão (norte)   | Arquearia, Resistência       | Isolamento             |
# | Aser       | Costa norte (Aco)         | Ofício, Agricultura          | Riqueza visível        |
# | Issacar    | Vale de Jezreel           | Trabalho, Resistência        | Lentidão               |
# | Zebulom    | Norte (costa)             | Comércio, Navegação          | Dependência de rotas   |
# | Efraim     | Centro (montanhas)        | Fertilidade, Liderança norte | Inveja das tribos      |
# | Manassés   | Centro e Leste (Gileade)  | Guerreiros, Terra dobrada    | Divisão territorial    |
# | Benjamim   | Centro (Jerusalém/Jericó) | Guerreiros leais             | Temperamento explosivo |
# - continuação
#
# | Povo        | Origem Bíblica             | Região Principal             | Hostilidade a Israel | Vantagens Principais                             | Desvantagens Principais              |
# | ----------- | -------------------------- | ---------------------------- | -------------------- | ------------------------------------------------ | ------------------------------------ |
# | Amoritas    | filho de Canaã (Gn 10:16)  | Montanhas de Canaã e Gileade | Hostil                 | Trabalho, Ofício, Luta (montanha)                | Diplomacia (nômades)                 |
# | Heteus      | filho de Canaã (Gn 10:15)  | Hebrom e sul de Canaã        | Hostil               | Ofício (ferro), Diplomacia (reinos)              | Sobrevivência (longe de cidades)     |
# | Jebuseus    | filho de Canaã (Gn 10:16)  | Jerusalém (Jebus)            | Hostil               |Furtividade, Percepção (urbano), Vontade (cerco) | Diplomacia (deserto/planície)        |
# | Heveus      | filho de Canaã (Gn 10:17)  | Líbano e Siquém              | Aliança/Hostil       |Diplomacia, Intuição, Sobrevivência (paz)        | Luta (iniciar combate)               |
# | Girgaseus   | filho de Canaã (Gn 10:16)  | Canaã central                | Hostil               |Sobrevivência, História, Teologia (Canaã)        | Liderança (fora da região)           |
# | Ferezeus    | cananeus (Gn 13:7)         | Aldeias abertas de Canaã     | Hostil               |Ofício, Sobrevivência, Liderança (aldeia)        | Vontade (cerco)                      |
# | Midianitas  | filho de Abraão (Gn 25:2)  | Noroeste da Arábia           | Variável             |Sobrevivência, Arquearia, Diplomacia (rotas)     | Ofício (oficina fixa)                |
# | Amalequitas | neto de Esaú (Gn 36:12)    | Neguebe e Sinai              | Hostil               |Luta, Resistência, Furtividade (deserto)         | Diplomacia (hebreus)                 |
# | Azeus       |||| Luta, Resistência (planície), Lida com animais   | Furtividade (terreno acidentado)     |
# | Moabitas    | filho de Ló (Gn 19:37)     | Leste do Mar Morto           | Hostil               |Ofício, Sobrevivência, Diplomacia (força)        | Vontade (maldições)                  |
# | Amonitas    | filho de Ló (Gn 19:38)     | Norte de Moabe               | Hostil               |Percepção, Vontade, Teologia (próprio culto)     | Diplomacia (estrangeiros)            |
# | Edomitas    | filho de Isaque (Gn 25:30) | Montanhas de Seir            | Hostil               |Luta, Sobrevivência, Intuição (hebreus)          | Diplomacia (hebreus)                 |
# | Ismaelitas  | filho de Abraão (Gn 16:15) | Norte da Arábia              | Variável             |Diplomacia, Sobrevivência, Arquearia (deserto)   | Ofício (urbano), Diplomacia (cortes) |

# %% [markdown]
# ## Hebreus pré-Israel
#
# ### Vantagens
#
# - **Fé inabalável**: Vantagem em testes de Vontade contra medo, tentação ou maldições.
#
# - **Resiliência do deserto**: Vantagem em testes de Sobrevivência em ambientes áridos.
#
# ### Desvantagem
#
# **Povo perseguido**: Desvantagem em testes de Diplomacia com egípcios e alguns cananeus hostis.

# %% [markdown]
# ### Rúben
#
# #### História
# Primogênito de Jacó com Léia. Perdeu a primogenitura por deitar-se com a concubina de seu pai, Bila.
#
# Sua tribo recebeu terra a leste do Jordão.
#
# #### Região (após conquista da Terra Prometida)
# Leste do Jordão, sul de Gileade, entre os rios Arnom e Jaboque.
#
# #### Referências
# - "³¹ Vendo o Senhor que Lia era desprezada, fê-la fecunda; ao passo que Raquel era estéril.
# ³² Concebeu, pois, Lia e deu à luz um filho, a quem chamou Rúben, pois disse: O Senhor atendeu à minha aflição. Por isso, agora me amará meu marido." (Gênesis 29:31-32, ARA)
#
# - "³ Rúben, tu és meu primogênito, minha força e as primícias do meu vigor, o mais excelente em altivez e o mais excelente em poder.
# ⁴ Impetuoso como a água, não serás o mais excelente, porque subiste ao leito de teu pai e o profanaste; subiste à minha cama." (Gênesis 49:3-4, ARA)
#
# #### Líderes
#
# - Datã, Abirão e Coré (Números 16)
#
# - Eliasafe, filho de Seuel (Números 3:30)
#
# ### Cidades
#
# - Hesbom
#
# - Dibom
#
# - Aroer
#
# - Bezer
#
# #### Vantagens
# - **Primogênito**: Vantagem em testes de Liderança dentre as tribos.
#
# - **Pastores do deserto**: Vantagem em testes de Sobrevivência.
#
# #### Desvantagem
# - **Instabilidade moral**: Desvantagem em testes de Vontade contra tentações de poder.

# %% [markdown]
# ### Simeão
#
# #### História
# Segundo filho de Jacó com Léia. Violento, participou do massacre de Siquém. Prometido ser disperso em Israel. Recebeu terras no sul de Judá.
#
# #### Região (após conquista da Terra Prometida)
# Situado ao Sul de Canaã, ao norte do desertos de Zim (Sim). Cercado pela tribo de Judá.
#
# #### Referências
# - "E concebeu outra vez e deu à luz um filho, dizendo: Porquanto o SENHOR ouviu que era desprezada, deu-me também este. E chamou o seu nome Simeão." (Gênesis 29:33, ACF)
# - "²⁵ Ao terceiro dia, quando os homens sentiam mais forte a dor, dois filhos de Jacó, Simeão e Levi, irmãos de Diná, tomaram cada um a sua espada, entraram inesperadamente na cidade e mataram os homens todos.
# ²⁶ Passaram também ao fio da espada a Hamor e a seu filho Siquém; tomaram a Diná da casa de Siquém e saíram." (Gênesis 34:25,26, ARA)
# - "⁵ Simeão e Levi são irmãos; as suas espadas são instrumentos de violência.
# ⁶ No seu conselho, não entre minha alma; com o seu agrupamento, minha glória não se ajunte; porque no seu furor mataram homens, e na sua vontade perversa jarretaram touros.
# ⁷ Maldito seja o seu furor, pois era forte, e a sua ira, pois era dura; dividi-los-ei em Jacó e os espalharei em Israel." (Gênesis 49:5-7, ARA)
#
# #### Líderes
#
# - Zinri, filho de Salmu (Números 25:14)
#
# - Simei (1 Reis 2:36-46)
#
# #### Cidades
#
# - Berseba
#
# - Molada
#
# - Hazar-Sual
#
#
# #### Vantagens
# - **Guerreiros violentos**: Vantagem em testes de Luta contra inimigos numerosos.
#
# - **Justiça implacável**: Vantagem em testes de Liderança.
#
# #### Desvantagem
# **Fúria cega**: Desvantagem em testes de Intuição para perceber armadilhas emocionais.

# %% [markdown]
# ### Levi
# #### História
# Terceiro filho de Jacó com Léia. Participou do massacre de Siquém. Consagrado ao serviço do Tabernáculo. Não recebeu terra própria, mas cidades espalhadas por Israel.
#
# #### Região (após conquista da Terra Prometida)
# Cidades espalhadas por todas as tribos (48 cidades), sem território próprio.
#
# #### Referências
# - "E concebeu outra vez e deu à luz um filho, e disse: Porquanto o SENHOR ouviu que era desprezada, deu-me também este. E chamou o seu nome Levi." (Gênesis 29:34, ACF)
#
# - "²⁵ Ao terceiro dia, quando os homens sentiam mais forte a dor, dois filhos de Jacó, Simeão e Levi, irmãos de Diná, tomaram cada um a sua espada, entraram inesperadamente na cidade e mataram os homens todos.
# ²⁶ Passaram também ao fio da espada a Hamor e a seu filho Siquém; tomaram a Diná da casa de Siquém e saíram." (Gênesis 34:25,26, ARA)
#
# - "⁵ Simeão e Levi são irmãos; as suas espadas são instrumentos de violência.
# ⁶ No seu conselho, não entre minha alma; com o seu agrupamento, minha glória não se ajunte; porque no seu furor mataram homens, e na sua vontade perversa jarretaram touros.
# ⁷ Maldito seja o seu furor, pois era forte, e a sua ira, pois era dura; dividi-los-ei em Jacó e os espalharei em Israel." (Gênesis 49:5-7, ARA)
#
# - "²⁰ Disse também o Senhor a Arão: Na sua terra, herança nenhuma terás e, no meio deles, nenhuma porção terás. Eu sou a tua porção e a tua herança no meio dos filhos de Israel. (Números 18:20, ARA)
#
# #### Líderes
#
# - Arão (sumo sacerdote)
#
# - Eleazar (sumo sacerdote)
#
# - Moisés (levita, líder de Israel)
#
# - Corá (levita rebelde)
#
# #### Cidades
#
# São 48 cidades espalhadas por Israel (Josué 21):
#
# - Família de Coate (Clã Sacerdotal de Arão)
#   - Tribo de Judá e Simeão (9 cidades): Hebrom, Libna, Jatir, Estemoa, Holom, Debir, Aim, Jutá e Bete-Semes (com suas pastagens).
#   - Tribo de Benjamim (4 cidades): Gibeom, Geba, Anatote e Almom.
#   - Tribo de Efraim (4 cidades): Siquém, Gezer, Quibezaim e Bete-Horom.
#   - Tribo de Dã (4 cidades): Elteque, Gibetom, Aijalom e Gate-Rimom.
#   - Tribo de Manassés ocidental (2 cidades): Taanaque e Gate-Rimom.
#   - Tribo de Issacar (4 cidades): Usiote, Rasiote, Jarmute e En-Ganim.
# - Família de Gérson
#   - Tribo de Manassés oriental (1 cidade): Golã (em Basã).
#   - Tribo de Issacar (4 cidades): Cisiom, Dabrate, Jarmute e En-Ganim (ou readequadas no texto).
#   - Tribo de Aser (4 cidades): Misal, Abdom, Helcate e Reobe.
#   - Tribo de Naftali (3 cidades): Quedes (na Galileia), Hamote-Dor e Cartã.
# - Família de Merari
#   - Tribo de Zebulom (4 cidades): Jocneão, Cartá, Dimna e Naalal.
#   - Tribo de Rúben (4 cidades): Bezer, Jasa, Quedemote e Mefaate.
#   - Tribo de Gade (4 cidades): Ramote (em Gileade), Maanaim, Hesbom e Jazer.
# - As 6 Cidades de Refúgio
#   - A oeste do Jordão: Quedes, Siquém e Hebrom.
#   - A leste do Jordão (Transjordânia): Bezer, Ramote e Golã.
#
# #### Vantagens
# - **Tribo sacerdotal**: Vantagem em testes Performance e Cura.
#
# - **Unção sagrada**: Vantagem em testes de Vontade para situações espirituais.
#
# #### Desvantagem
# **Sem terra**: Desvantagem em testes de Trabalho e Ofício, visto que não foram treinados para outras atribuições fora do templo.

# %% [markdown]
# ### Judá
# #### História
# Quarto filho de Jacó com Léia. Recebeu a bênção de realeza. Davi, Salomão e o Messias vieram desta tribo. Líder natural das tribos.
#
# #### Região (após conquista da Terra Prometida)
# Sul de Canaã, ao redor das montanhas de Judá, Jerusalém, Hebrom.
#
# #### Referências
# - "35 De novo concebeu e deu à luz um filho; então, disse: Esta vez louvarei o Senhor. E por isso lhe chamou Judá; e cessou de dar à luz." (Gênesis 29:35, ACF)
#
#
# - "⁸ Judá, teus irmãos te louvarão; a tua mão estará sobre a cerviz de teus inimigos; os filhos de teu pai se inclinarão a ti.
# ⁹ Judá é leãozinho; da presa subiste, filho meu. Encurva-se e deita-se como leão e como leoa; quem o despertará?
# ¹⁰ O cetro não se arredará de Judá, nem o bastão de entre seus pés, até que venha Siló; e a ele obedecerão os povos." (Gênesis 49:8-10, ARA)
#
# #### Líderes
#
# - Davi (rei de Judá e Israel)
#
# - Salomão (rei)
#
# - Roboão (rei de Judá)
#
# - Ezequias (rei)
#
# - Josias (rei)
#
# #### Cidades
#
# - Jerusalém (capital)
#
# - Hebrom
#
# - Betel
#
# - Lais
#
# - Belém
#
# #### Vantagens
# - **Liderança real**: Vantagem em testes de Liderança e Diplomacia com outras tribos.
#
#
# #### Desvantagem
# **Alvo de inveja**: Desvantagem em testes de Furtividade quando em grupo.

# %% [markdown]
# ### Dã
#
# #### História
# Quinto filho de Jacó e o primeiro com Bila, serva de Raquel. Tornou-se juiz e guerreiro. Buscou novas terras ao norte.
#
# #### Região (após conquista da Terra Prometida)
# Norte de Canaã, região de Lais/Dã, perto do monte Hermom.
#
# #### Referências
# - "E disse Raquel: Deus me julgou... e chamou o seu nome Dã." (Gênesis 30:6, ACF)
# - "¹⁶ Dã julgará o seu povo, como uma das tribos de Israel.
# ¹⁷ Dã será serpente junto ao caminho, uma víbora junto à vereda, que morde os calcanhares do cavalo, e faz cair o seu cavaleiro por detrás." (Gênesis 49:16-17, ACF)
#
# #### Líderes
#
# - Samuel (juiz, de Dã)
#
# - Jefté (juiz)
#
# #### Cidades
#
# - Dã (Lais)
#
# - Zora
#
# - Estaol
#
# #### Vantagens
# - **Juízes e sentinelas**: Vantagem em testes de Percepção e Intuição.
#
# - **Guerreiros astutos**: Vantagem em testes de Furtividade em emboscadas.
#
# #### Desvantagem
# **Terra distante**: Desvantagem em testes de Sobrevivência fora de Dã.

# %% [markdown]
# ### Naftali
# #### História
# Sexto filho de Jacó e segundo com Bila, serva de Raquel. Recebeu bênção de liberdade e prosperidade.
#
# #### Região (após conquista da Terra Prometida)
# Ao norte de Canaã, vale de Jezreel, Genesaré, montanhas da Galileia.
#
# #### Referências
# - "⁸ Então disse Raquel: Com grandes lutas tenho lutado com minha irmã; também venci; e chamou o seu nome Naftali." (Gênesis 30:8, ACF)
#
# - "²¹ Naftali é uma gazela solta; ele dá palavras formosas." (Gênesis 49:21, ACF)
#
# #### Líderes
#
# - Baraque (juiz)
#
# - Débora (juíza)
#
# #### Cidades
#
# - Cades
#
# - Hamate
#
# - Tiberíades (posterior)
#
# #### Vantagens
# - **Mensageiros ágeis**: Vantagem em testes de Acrobacia e Performance.
#
# #### Desvantagem
# **Fronteira exposta**: Desvantagem em testes de Resistência contra invasões.

# %% [markdown]
# ### Gade
# #### História
# Sétimo filho de Jacó e primeiro com Zilpa, serva de Léia (ou Lia). Guerreiro que liderou na conquista, recebeu terra a leste do Jordão.
#
# #### Região (após conquista da Terra Prometida)
# Leste do Jordão, norte de Gileade, entre os rios Jaboque e Hermom. A oeste de suas terras se estabeleciam os Amonitas.
#
# #### Referências
# - "Então disse Lia: Afortunada! E chamou o seu nome Gade. (Gênesis 30:11, ACF)
#
# - "Quanto a Gade, uma tropa o acometerá; mas ele a acometerá por fim." (Gênesis 49:19, ACF)
#
# #### Líderes
#
# - Eliasafe, filho de Reuel (Números 2:14)
#
# #### Cidades
#
# - Ramote
#
# - Mahanaim
#
# - Hesbom
#
# #### Vantagens
# - **Guerreiros da fronteira**: Vantagem em testes de Arquearia e Resistência.
#
# - **Defensores de gileade**: Vantagem em testes de Luta em terreno montanhoso.
#
# #### Desvantagem
# **Isolamento**: Desvantagem em testes de Diplomacia com povos fora de sua região.

# %% [markdown]
# ### Aser
#
# #### História
# Oitavo filho de Jacó e segundo com Zilpa, serva de Léia. Recebeu bênção de abundância e terra fértil.
#
# #### Região (após conquista da Terra Prometida)
# Costa norte de Canaã, vale de Aco, próximo ao mar Mediterrâneo.
#
# #### Referências
# - "Então disse Lia: Para minha ventura; porque as filhas me terão por bem-aventurada; e chamou o seu nome Aser." (Gênesis 30:13, ACF)
# - "De Aser, o seu pão será gordo, e ele dará delícias reais." (Gênesis 49:20, ACF)
#
# #### Líderes
#
# - Paguel, filho de Ocrão (Números 2:27)
#
# #### Cidades
#
# - Aco
#
# - Sidom (fronteira)
#
# - Tiro (fronteira)
#
# #### Vantagens
# - **Artesãos e agricultores**: Vantagem em testes de Ofício e Sobrevivência.
#
# - **Riqueza da costa**: Vantagem em testes de Trabalho em comércio.
#
# #### Desvantagem
# **Riqueza visível**: Desvantagem em testes de Furtividade quando carregando bens.

# %% [markdown]
# ### Issacar
# #### História
# Nono filho de Jacó, quinto com Léia. Recebeu bênção de trabalho e prosperidade agrícola.
#
# #### Região (após conquista da Terra Prometida)
# Vale de Jezreel, norte de Canaã, terras férteis entre as tribos do norte.
#
# #### Referências
# - "Então disse Lia: Deus me tem dado o meu galardão, pois tenho dado minha serva ao meu marido. E chamou o seu nome Issacar." (Gênesis 30:18, ACF)
# - "¹⁴ Issacar é jumento de fortes ossos, deitado entre dois fardos.
# ¹⁵ E viu ele que o descanso era bom, e que a terra era deliciosa e abaixou seu ombro para acarretar, e serviu debaixo de tributo." (Gênesis 49:14-15, ACF)
#
# #### Líderes
#
# - Nathanael, filho de Zuar (Números 2:5)
#
# #### Cidades
#
# - Jezreel
#
# - Siquém
#
# - Suném
#
# #### Vantagens
# - **Transportadores**: Vantagem em testes de Trabalho e Resistência, por exemplo, ao levar carga.
#
# - **Agricultores abençoados**: Vantagem em testes de Sobrevivência.
#
# #### Desvantagem
# **Lentidão**: Desvantagem em testes de Acrobacia e movimentos rápidos.

# %% [markdown]
# ### Zebulom
#
# #### História
# Décimo filho de Jacó e sexto com Léia. Recebeu bênção de comércio e moradia na costa.
#
# #### Região (após conquista da Terra Prometida)
# Norte de Canaã, vale de Jezreel, próximo ao mar Mediterrâneo.
#
# #### Referências
# - "E disse Lia: Deus me deu uma boa dádiva; desta vez morará o meu marido comigo, porque lhe tenho dado seis filhos. E chamou o seu nome Zebulom." (Gênesis 30:20, ACF)
# - "Zebulom habitará no porto dos mares, e será como porto dos navios, e o seu termo será para Sidom." (Gênesis 49:13, ACF)
#
# #### Líderes
#
# - Eliabe, filho de Helom (Números 2:7)
#
# #### Cidades
#
# - Aco
#
# - Sidom (fronteira)
#
# - Tiro (fronteira)
#
# #### Vantagens
# - **Comerciantes do mar**: Vantagem em testes de Diplomacia e Intuição.
#
# - **Porto seguro**: Vantagem em testes de Trabalho no mar Navegação e comércio marítimo.
#
# #### Desvantagem
# **Dependência de rotas**: Desvantagem em testes de Sobrevivência longe de rotas comerciais.

# %% [markdown]
# ### Efraim, filho de José
#
# #### História
# Filho mais novo de José, mas abençoado por Jacó como primogênito. Tornou-se a tribo mais poderosa do norte.
#
# #### Região (após conquista da Terra Prometida)
# Centro de Canaã, montanhas de Efraim, Siquém, compreendendo Siló, Betel e Ai.
#
# #### Referências
#
# - "² E ao nome do segundo chamou Efraim; porque disse: Deus me fez crescer na terra da minha aflição." (Gênesis 41:52, ACF)
#
# - "⁴ Assim alcançaram a sua herança os filhos de José, Manassés e Efraim.
# ⁵ E foi o termo dos filhos de Efraim, segundo as suas famílias, como se segue: o termo da sua herança para o oriente era Atarote-Adar até Bete-Horom de cima; "(Josué 16:4-5 ACF)
#
# #### Líderes
#
# - Josué (de Efraim, sucessor de Moisés)
#
# - Gideão (de Efraim, juiz)
#
# - Jefté (de Efraim, juiz)
#
# #### Cidades
#
# - Siquém
#
# - Betel
#
# - Siló
#
# - Samaria (posterior)
#
# #### Vantagens
# - **Fertilidade e prosperidade**: Vantagem em testes de História e Teologia.
#
# - **Liderança no norte**: Vantagem em testes de Liderança entre tribos do norte.
#
# #### Desvantagem
# **Inveja das tribos**: Desvantagem em testes de Liderança sobre as tribos de Judá e Benjamin.

# %% [markdown]
# ### Manassés, filho de José
#
# #### História
# Filho mais velho de José. Recebeu terras a leste e oeste do Jordão.
#
# #### Região (após conquista da Terra Prometida)
# Oeste: centro de Canaã; Leste: norte de Gileade, Basã.
#
# #### Referências
# - "E chamou José o nome do primogênito Manassés, porque disse: Deus me fez esquecer de todo o meu trabalho, e de toda a casa de meu pai." (Gênesis 41:51, ACF)
#
# - "⁵ E couberam a Manassés dez quinhões, afora a terra de Gileade e Basã, que está além do Jordão;
# ⁶ Porque as filhas de Manassés receberam herança entre os filhos dele; e os outros filhos de Manassés ficaram com a terra de Gileade." (Josué 17:5-6, ACF)
#
# #### Líderes
#
# - Gideão (de Manassés, juiz)
#
# - Jefté (de Manassés, juiz)
#
# #### Cidades
#
# - Gileade
#
# - Basã
#
# - Astarote
#
#
#
# #### Vantagens
# - **Guerreiros e líderes**: Vantagem em testes de Luta e Liderança.
#
# - **Terra dobrada**: Vantagem em testes de Sobrevivência em territórios próprios.
#
# #### Desvantagem
#  **Divisão territorial**: Desvantagem em testes de Percepção para notar ameaças em fronteiras divididas.

# %% [markdown]
# ### Benjamim
# #### História
# Décimo segundo filho de Jacó e segundo com Raquel (após José). Nasceu em Belém. De sua tribo veio Saul, o primeiro rei de Israel.
#
# #### Região (após conquista da Terra Prometida)
# Centro de Canaã, entre Judá e Efraim, incluindo Jerusalém (dividida), Jericó e Gibeá.
#
# #### Referências
# - "E aconteceu que, saindo-se-lhe a alma (porque morreu), ela chamou o seu nome Benoni; mas seu pai chamou-lhe Benjamim." (Gênesis 35:18, ACF)
#
# - "Benjamim é lobo que despedaça; pela manhã comerá a presa, e à tarde repartirá o despojo." (Gênesis 49:27, ACF)
#
# #### Líderes
#
# - Saul (primeiro rei de Israel)
#
# - Jônatas (filho de Saul)
#
# - Mardoqueu (livro de Ester)
#
# - Ester (rainha)
#
# #### Cidades
#
# - Jerusalém (parte)
#
# - Jericó
#
# - Gibeá
#
# - Mizpá
#
# #### Vantagens
# - **Guerreiros leais**: Vantagem em testes de Luta quando defendendo aliados.
#
# - **Lobo feroz**: Vantagem em testes de Liderança em combate.
#
# #### Desvantagem
# **Temperamento explosivo**: Desvantagem em testes de Diplomacia após conflitos.

# %% [markdown]
# ## Egípcios
#
# ### História
# São descendentes de Mizraim, filho de Cam, neto de Noé. Povo dominante do Nilo, com faraós, sacerdotes e escribas. Subjugaram os hebreus por 400 anos até o Êxodo liderado por Moisés.
#
# ### Região
# Vale do Nilo, do delta ao sul (Alto Egito), atual Egito.
#
# ### Referências
# - "E Cão gerou a Cuxe e a Mizraim..." (Gênesis 10:6, ACF)
#
# - "E o Faraó disse a José: Eis que toda a terra do Egito está diante de ti..." (Gênesis 47:6, ACF)
#
# - "E José faleceu, e também todos os seus irmãos... E os filhos de Israel frutificaram, e aumentaram muito, e multiplicaram-se, e foram fortalecidos grandemente; e a terra se encheu deles. E levantou-se um novo rei sobre o Egito, que não conhecera a José..." (Êxodo 1:6-8, ACF)
#
# ### Líderes Principais
# - Faraó do Êxodo (não nomeado na Bíblia, tradicionalmente associado a Ramsés II ou Merneptah)
#
# - Faraó de Abraão (Gênesis 12:10-20)
#
# - Faraó de José (Gênesis 41)
#
# - Faraó de Salomão (1 Reis 3:1; 9:16)
#
# ### Cidades Principais
# - Mênfis (capital antiga)
#
# - Tebas (capital religiosa)
#
# - Pi-Ramsés (cidade construída pelos hebreus)
#
# - Armazém (Ex 1:11)
#
# - Gósen (região onde os hebreus habitaram)
#
# ### Vantagens
# - **Civilização do Nilo**: Vantagem em testes de Ofício e História relacionados ao Egito.
#
# - **Poder sacerdotal**: Vantagem em testes de Teologia e rituais divinos.
#
# ### Desvantagem
# Arrogância imperial: Desvantagem em testes de Diplomacia com povos escravizados ou "bárbaros".
#
# ### Perícias
# Ofício, Teologia, História, Diplomacia

# %% [markdown]
# ## Filisteus
#
# ### História
# Povo originário do mar Egeu (Capitor), migraram para Canaã no século XII a.C. Inimigos históricos de Israel na época dos Juízes e Reis. Conhecidos por guerreiros como Golias.
#
# ### Região
# Cinco cidades principais: Gaza, Asquelom, Asdode, Gate e Ecrom. Costa sul de Canaã, atual faixa de Gaza e sul de Israel.
#
# ### Referências
# - "E ao jebuseu, ao amorreu, ao girgaseu, E ao heveu, ao arqueu, ao sineu, E ao arvadeu, ao zemareu, ao hamateu..." (Gênesis 10:17-18, ACF)
# - "E os filisteus ajuntaram as suas tropas para a guerra..." (1 Samuel 13:5, ACF)
# - "E saiu da campanha dos filisteus um homem guerreiro, cujo nome era Golias, de Gate..." (1 Samuel 17:4, ACF)
# - "E Davi se levantou, e passou com os seiscentos homens que estavam com ele, para Aquis, filho de Maoque, rei de Gate." (1 Samuel 27:2, ACF)
#
# ### Líderes Principais
# - Aquis, rei de Gate (1 Samuel 21:10-15; 27:1-12)
#
# - Reis da Pentápole: Gaza, Asdode, Ascalom, Gate, Ecrom
#
# - Golias de Gate (1 Samuel 17)
#
# - Sara, rei de Gerar (Gênesis 20)
#
# ### Cidades Principais (Pentápole)
# - Gaza
#
# - Asdode
#
# - Ascalom
#
# - Gate
#
# - Ecrom
#
# ### Vantagens
# - **Guerreiros do mar**: Vantagem em testes de Luta em terreno costeiro ou planície.
#
# - **Tecnologia de ferro**: Vantagem em testes de Ofício com armas e armaduras.
#
# ### Desvantagem
# **Invasores estrangeiros**: Desvantagem em testes de Diplomacia com povos nativos de Canaã.
#
# ### Perícias
# Luta, Ofício (armas), Percepção

# %% [markdown]
# ## Sidônios
# Também chamados Fenícios.
#
# ### História
# Descendentes de Sidom, primogênito de Canaã. Povo de comerciantes e navegadores, conhecidos por Sidom e Tiro. Mestres em construção naval e comércio marítimo.
#
# ### Região
# Costa do Líbano, atual Líbano, cidades de Sidom, Tiro e Beirute.
#
# ### Referências
# - "E Canaã gerou a Sidom, seu primogênito, e a Hete..." (Gênesis 10:15, ACF)
#
# - "...Sidom a grande, que está ao lado do caminho que vai para a torre de Hamate..." (Números 34:7-8, ACF)
#
# ### Líderes Principais
# - Rei de Sidom (Juízes 10:12)
#
# - Hiram, rei de Tiro (aliado de Davi e Salomão - 2 Samuel 5:11; 1 Reis 5:1)
#
# - Jezabel (princesa de Sidom, esposa de Acabe - 1 Reis 16:31)
#
# - Rainha de Tiro (Ezequiel 28)
#
# ### Cidades Principais
# - Sidom (cidade principal)
#
# - Tiro (cidade-irmã)
#
# - Beirute
#
# - Zarefate
#
# ### Vantagens
#
# - **Senhores do mar**: Vantagem em testes de Diplomacia e Comércio em portos.
#
# - **Artesãos da madeira**: Vantagem em testes de Ofício com madeira e construção naval.
#
# ### Desvantagem
#
# **Comércio acima de tudo**: Desvantagem em testes de Vontade contra suborno ou ganância.
#
# ### Perícias
# Diplomacia, Ofício (madeira), Navegação

# %% [markdown]
# ## Cananeus (povos de Canaã)
#
# ### Origem
# Descendentes de Canaã, filho de Cam, neto de Noé.
#
# ### Região
# Terra de Canaã — costa oriental do Mediterrâneo, do Líbano ao sul de Gaza, e do Jordão ao Mediterrâneo.
#
# ### Referência
#
# "E Canaã gerou a Sidom, seu primogênito, e a Hete; E ao jebuseu, ao amorreu, ao girgaseu, E ao heveu, ao arqueu, ao sineu..." (Gênesis 10:15-17, ACF)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###  Amoritas
# Também chamados Amorreus.
#
# #### História
# Povo que habitava a região montanhosa de Canaã e parte oriental do Rio Jordão. Foram um dos principais grupos que Israel enfrentou na conquista.
#
# #### Região
# Região montanhosa ao leste e oeste do Jordão, incluindo Basã e Gileade.
#
# #### Referências
#
# "Levantai-vos, parti e ide à região montanhosa dos amorreus..." (Deuteronômio 1:7, ACF)
#
# "E feriram a Seom, rei dos amorreus, que habitava em Hesbom..." (Números 21:25, ACF)
#
# #### Líderes
#
# - Seom, rei de Hesbom (Números 21:21-32)
#
# - Ogue, rei de Basã (Números 21:33-35)
#
# #### Cidades
#
# - Hesbom
#
# - Basã
#
# - Astarote
#
# - Edrei
#
# #### Vantagens
#
# - **Construtores de montanha**: Vantagem em testes de Trabalho e Ofício em terreno montanhoso.
#
# - **Guerreiros de pedra**: Vantagem em testes de Luta quando em terreno elevado.
#
# #### Desvantagem
#
# Orgulho ancestral: Desvantagem em testes de Diplomacia com povos nômades ou "inferiores".
#
# #### Perícias
# Trabalho, Ofício, Luta

# %% [markdown]
# ### Heteus
# #### História
# Descendentes de Hete, filho de Canaã. Habitavam cidades fortificadas e eram conhecidos por sua força.
#
# #### Região
# Sul de Canaã, especialmente em Hebrom e arredores.
#
# #### Referência
#
# - "E Canaã gerou... a Hete; E ao jebuseu, ao amorreu..." (Gênesis 10:15-16, ACF)
#
# - "Levanta-te, percorre esta terra... e entra em Hebrom... onde estão os filhos de Anaque, e os heteus..." (Números 13:22, ACF)
# Vantagens:
#
# #### Líderes
#
# - Efrom, o heteu (Gênesis 23)
#
# - Urias, o heteu (2 Samuel 11)
#
# #### Cidades
#
# - Hebrom (Quiriate-Arba)
#
# - Betel (Juízes 1:23-26)
#
# #### Vantagens
#
# - **Senhores do ferro**: Vantagem em testes de Ofício com armas e armaduras.
#
# - **Diplomacia imperial**: Vantagem em testes de Diplomacia com reinos organizados.
#
# #### Desvantagem
#
# **Inimigos distantes**: Desvantagem em testes de Sobrevivência longe de suas cidades ou rotas comerciais.
#
# #### Perícias
# Ofício, Diplomacia

# %% [markdown]
# ### Jebuseus
#
# Habitantes de Jerusalém.
#
# #### História
# Habitantes de Jerusalém, então chamada Jebus. Resistiram à conquista da Terra Prometida por muito tempo.
#
# #### Região
# Região montanhosa de Jerusalém e arredores.
#
# #### Referências
#
# - "E ao jebuseu..." (Gênesis 10:16, ACF)
#
# - "Porém os filhos de Judá não puderam expulsar os jebuseus, que habitavam em Jerusalém..." (Juízes 1:21, ACF)
#
# #### Líderes
#
# - Rei de Jerusalém (Josué 10:1-5)
#
# #### Cidades
#
# - Jerusalém (Jebus)
#
# #### Vantagens
#
# - **Mestres da cidade-fortaleza**: Vantagem em testes de Furtividade e Percepção em terreno urbano.
#
# - **Resistência sitiada**: Vantagem em testes de Vontade durante cercos ou defesas.
#
# #### Desvantagem
#
# Isolamento montanhês: Desvantagem em testes de Diplomacia com povos do deserto ou planície.
#
# #### Perícias
# Furtividade, Percepção, Vontade

# %% [markdown]
# ### Heveus
#
# #### História
# Povo que habitava o norte de Canaã, perto do monte Hermom. Fizeram aliança com Josué.
#
# #### Região
# Região montanhosa do Líbano e arredores de Siquém.
#
# #### Referências
# - "E ao heveu..." (Gênesis 10:17, ACF)
#
# - "Os heveus, no monte Hermom, até à entrada de Hamate..." (Juízes 3:3, ACF)
#
# #### Líderes
#
# - Hamor, o heveu (Gênesis 34)
#
# - Siquém, filho de Hamor (Gênesis 34)
#
# #### Cidades
#
# - Siquém
#
# - Gibeom (Josué 9)
#
# #### Vantagens
#
# - **Pactuadores**: Vantagem em testes de Diplomacia e Intuição em negociações.
#
# - **Adaptação pacífica**: Vantagem em testes de Sobrevivência quando não em combate.
#
# #### Desvantagem
#
# **Evitam conflito**: Desvantagem em testes de Luta quando Iniciam combate.
#
# #### Perícias
# Diplomacia, Intuição, Sobrevivência

# %% [markdown]
# ### Girgaseus
#
# #### História
# Povo cananeu mencionado nas listas de nações a serem expulsas. Poucos detalhes específicos.
#
# #### Região
# Provavelmente região central de Canaã.
#
# #### Referência
#
# "E ao jebuseu, ao amorreu, ao girgaseu..." (Gênesis 10:16, ACF)
#
# #### Líderes
#
# (não nomeados especificamente)
#
# #### Cidades
#
# (região central de Canaã)
#
# #### Vantagens
#
# - **Conhecedores da terra**: Vantagem em testes de Sobrevivência e História em Canaã.
#
# - **Raízes antigas**: Vantagem em testes de Teologia sobre cultos locais.
#
# #### Desvantagem
#
# **Povo esquecido**: Desvantagem em testes de Liderança fora de sua região natal.
#
# #### Perícias
# Sobrevivência, História, Teologia

# %% [markdown]
# ### Azeus
# Também conhecidos como Azeveus.
#
# #### História
# Povo cananeu mencionado junto com outros. Provavelmente aldeões ou guerreiros da planície.
#
# #### Região
#
# Planícies de Canaã.
#
# #### Líderes
#
# (habitantes de aldeias, sem reis específicos)
#
# #### Cidades
#
# Aldeias abertas em Canaã.
#
# #### Vantagens
#
# - **Guerreiros da planície**: Vantagem em testes de Luta e Resistência em terreno aberto.
#
# - **Cavaleiros antigos**: Vantagem em testes de Lida com animais (cavalos/carros de guerra).
#
# #### Desvantagem
#
# **Pouca flexibilidade**: Desvantagem em testes de Furtividade em terreno acidentado.
#
# #### Perícias
# Luta, Resistência

# %% [markdown]
# ### Ferezeus
# Habitantes de aldeias abertas
#
# #### História
# Habitantes de aldeias abertas ("sem muros"). Viveram entre os cananeus.
#
# #### Região
# Região montanhosa e aldeias de Canaã.
#
# #### Referência
#
# - "O cananeu e o ferezeu estavam então na terra..." (Gênesis 13:7, ACF)
#
# #### Líderes
#
# (habitantes de aldeias, sem reis específicos)
#
# #### Cidades
#
# Aldeias abertas em Canaã
#
# #### Vantagens
#
# - **Vida rural**: Vantagem em testes de Ofício (agricultura) e Sobrevivência.
#
# - **Comunidade unida**: Vantagem em testes de Liderança dentro de sua aldeia.
#
# #### Desvantagem
#
# **Sem fortificações**: Desvantagem em testes de Vontade durante cercos ou invasões.
#
# #### Perícias
# Ofício, Sobrevivência, Liderança

# %% [markdown]
# ## Midianitas
#
# ### História
# Descendentes de Midiã, filho de Abraão com Quetura. Nômades do deserto, comerciantes. Tiveram contato com Moisés (casou-se com Zípora, midianita).
#
# ### Região
# Noroeste da Arábia, golfo de Aqaba, sul de Edom.
#
# ### Referências
#
# - "E Abraão tomou outra mulher; o seu nome era Quetura. E ela lhe deu à luz... a Midiã..." (Gênesis 25:1-2, ACF)
#
# - "E os midianitas o venderam no Egito..." (Gênesis 37:28, ACF)
#
# - "E teve Moisés apascentando o rebanho de Jetro, seu sogro, sacerdote em Midiã..." (Êxodo 3:1, ACF)
#
# ### Líderes Principais
# - Jetro, sacerdote de Midiã (sogro de Moisés - Êxodo 3:1)
#
# - Zípora (filha de Jetro, esposa de Moisés)
#
# - Reis de Midiã (Números 31:8): Evi, Requém, Zur, Hur, Reba
#
# - Cores, midianita (Juízes 8)
#
# ### Cidades Principais
# - Midiã (região, não cidade específica)
#
# - Acabe (região)
#
# - Quisom (região)
#
# ### Vantagens
# - **Senhores das rotas**: Vantagem em testes de Sobrevivência e Diplomacia em rotas comerciais.
#
# - **Arqueiros do deserto**: Vantagem em testes de Arquearia em terreno aberto.
#
# ### Desvantagem
#
# **Vida nômade**: Desvantagem em testes de Ofício que exijam oficina fixa.
#
# ### Perícias
# Sobrevivência, Arquearia, Diplomacia

# %% [markdown]
# ## Amalequitas
# ### História
# Povo nômade e guerreiro, descendente de Amaleque, neto de Esaú. Primeiros a atacar Israel após o Êxodo.
#
# ### Região
# Deserto do Neguebe, sul de Canaã, península do Sinai.
#
# ### Referências
#
# - "Amaleque foi o primeiro das nações, mas o seu fim será a destruição." (Números 24:20, ACF)
#
# - "Então veio Amaleque, e pelejou contra Israel em Refidim." (Êxodo 17:8, ACF)
#
# - "Vai, pois, agora, e fere a Amaleque..." (1 Samuel 15:2, ACF)
#
# ### Líderes Principais
# - Agague, rei dos amalequitas (1 Samuel 15:8-33)
#
# - Reis de Amaleque (Números 24:20)
#
# ### Cidades Principais
# - Região do Neguebe
#
# - Deserto de Parã
#
# - Península do Sinai
#
# ### Vantagens
#
# - **Guerreiros do deserto**: Vantagem em testes de Luta e Resistência em terreno árido.
#
# - **Ataque surpresa**: Vantagem em testes de Furtividade contra caravanas ou grupos cansados.
#
# ### Desvantagem
#
# Ódio ancestral: Desvantagem em testes de Diplomacia com hebreus (inimigos jurados).
#
# ### Perícias
# Luta, Resistência, Furtividade

# %% [markdown]
# ## Moabitas
# #### História
# Descendentes de Moabe, filho de Ló com sua filha primogênita. Habitavam a leste do Jordão. Hostis a Israel, mas com parentesco distante.
#
# ### Região
# Planalto a leste do Mar Morto, entre os rios Arnom e Zerede.
#
# ### Referências
#
# - "E a primogênita deu à luz um filho e chamou o seu nome Moabe; este é o pai dos moabitas até o dia de hoje." (Gênesis 19:37, ACF)
#
# - Então Balacom, rei de Moabe, ouviu tudo o que Israel fizera aos amorreus." (Números 22:2, ACF)
#
# - "Então o SENHOR me disse: Não molestes aos moabitas..." (Deuteronômio 2:9, ACF)
#
# ### Líderes Principais
# - Balacom, rei de Moabe (Números 22-24)
#
# - Eglom, rei de Moabe (Juízes 3:12-30)
#
# - Rute, a moabita (Rute 1:4)
#
# ### Cidades Principais
# - Dibom (capital)
#
# - Ar (Números 21:15)
#
# - Quiriate-Arba (Números 32:37)
#
# - Betel (Números 32:38)
#
# - Bete-Gamul (Números 32:38)
#
# ### Vantagens
# - **Agricultores do planalto**: Vantagem em testes de Ofício (agricultura) e Sobrevivência.
#
# - **Aliados convenientes**: Vantagem em testes de Diplomacia quando em posição de força.
#
# ### Desvantagem
#
# **Inveja de Israel**: Desvantagem em testes de Vontade contra maldições ou pragas.
#
# ### Perícias
# Ofício, Sobrevivência, Diplomacia

# %% [markdown]
# ## Amonitas
#
# ### História
# Descendentes de Ben-Ami, filho de Ló com sua filha mais nova. Irmãos dos moabitas, também hostis a Israel.
#
# ### Região
# Norte de Moabe, região de Jabes-Gileade, capital Rabá.
#
# ### Referências
#
# - "E a mais nova também deu à luz um filho e chamou o seu nome Ben-Ami; este é o pai dos filhos de Amom até o dia de hoje." (Gênesis 19:38, ACF)
#
# - "E quando te aproximares dos amonitas, não os molestes..." (Deuteronômio 2:19, ACF)
#
# - "Então saiu Naás, rei dos filhos de Amom..." (1 Samuel 11:1, ACF)
#
# ### Líderes Principais
# - Rei dos filhos de Amom (Juízes 11)
#
# - Naás, rei dos filhos de Amom (1 Samuel 11)
#
# - Sobeque, rei dos filhos de Amom (2 Samuel 10)
#
# ### Cidades Principais
# - Rabá (capital, atual Amã)
#
# - Jabes-Gileade
#
# - Aroer
#
# ### Vantagens
#
# - **Defensores do leste**: Vantagem em testes de Percepção e Vontade contra invasores.
#
# - **Culto próprio**: Vantagem em testes de Teologia sobre suas divindades.
#
# ### Desvantagem
#
# **Desconfiança estrangeira**: Desvantagem em testes de Diplomacia com povos de fora.
#
# ### Perícias
# Percepção, Vontade, Teologia

# %% [markdown]
# ## Edomitas
# Descendentes de Esaú.
#
# ### História
# Descendentes de Esaú, irmão de Jacó. Habitavam a região montanhosa de Seir. Eram parentes próximos de Israel, mas frequentemente hostis.
#
# ### Região
# Montanhas de Seir, sul do Mar Morto, atual sul da Jordânia.
#
# ### Referências
#
# - "E chamou o seu nome Edom... E habitou Esaú na montanha de Seir; Esaú é Edom." (Gênesis 36:1,8, ACF)
#
# - "E estes são os reis que reinaram na terra de Edom..." (Gênesis 36:31, ACF)
#
# - "Assim passou Edom, não deixando passar Israel pelos seus termos..." (Números 20:21, ACF)
#
# ### Líderes Principais
# - Reis de Edom (Gênesis 36:31-39):
#
# - Belá, filho de Beor
#
# - Jobabe, filho de Zera
#
# - Husão da terra dos temanitas
#
# - Hadade, filho de Bedade
#
# - Sama de Masreca
#
# - Saul de Reobote
#
# - Baal-Hanã, filho de Acbor
#
# - Hadade
#
# ### Cidades Principais
# - Sela (capital)
#
# - Teman
#
# - Bozra
#
# - Enom
#
# - Ezion-Geber
#
# ### Vantagens
#
# - **Guerreiros das montanhas**: Vantagem em testes de Luta e Sobrevivência em terreno rochoso.
#
# - **Irmãos de sangue**: Vantagem em testes de Intuição contra hebreus (conhecem seus costumes).
#
# ### Desvantagem
#
# **Rivalidade fraternal**: Desvantagem em testes de Diplomacia com hebreus (tensão histórica).
#
# ### Perícias
# Luta, Sobrevivência, Intuição

# %% [markdown]
# ## Ismaelitas
#  Nômades do deserto.
#
# ### História
# Descendentes de Ismael, filho de Abraão com Hagar. Nômades do deserto, comerciantes.
#
# ### Região
# Norte da Arábia, deserto de Parã, península do Sinai.
#
# ### Referências
#
# - "E estes são os nomes dos filhos de Ismael... habitaram desde Havilá até Sur..." (Gênesis 25:13-18, ACF)
#
# - "E os midianitas o venderam no Egito a Potifar... e os ismaelitas o levaram ao Egito." (Gênesis 37:28,36, ACF)
#
# ### Líderes Principais
#
# - Ismael (Gênesis 25:12-18)
#
# - Nebaote (primogênito de Ismael)
#
# - Cedar (filho de Ismael)
#
# - Adbeel, Mibsam, Misma, Duma, Massa, Hadade, Tema, Jetur, Nafis, Quedema (12 filhos de Ismael)
#
# ### Cidades Principais
# - Havilá (região)
#
# - Sur (região)
#
# - Deserto de Parã
#
# - Tema
#
# - Duma
#
# ### Vantagens
#
# - **Comerciantes do deserto**: Vantagem em testes de Diplomacia e Sobrevivência em rotas.
#
# - **Arqueiros nômades**: Vantagem em testes de Arquearia a cavalo.
#
# ### Desvantagem
#
# **Desprezo por cidades**: Desvantagem em testes de Ofício urbano ou Diplomacia em cortes reais.
#
# ### Perícias
# Diplomacia, Sobrevivência, Arquearia

# %% [markdown]
# # Treinamentos
# Os treinamentos representam as vocações fundamentais do povo de Deus em meio à história. Cada personagem pode ser formado para conselhar, construir, guardar, lutar, servir, mensagear, pastorear, profetizar ou ministrar diante do Senhor. Essas funções não são apenas ocupações; são maneiras de viver a fé em ação, servindo ao próximo e dependendo da direção de Deus.
#
# Eles mostram como o personagem foi formado, qual função ocupa e de que maneira ele serve o povo. Os treinamentos destacam vocações práticas, espirituais e comunitárias.

# %% [markdown]
# ## Conselheiro
# Os conselheiros aparecem em Israel como homens e mulheres de discernimento, chamados a sustentar o povo em tempos de incerteza. Sua força não está na espada, mas na palavra certa, no temor de Deus e na capacidade de ouvir antes de falar. Eles servem em disputas, decisões tribais e momentos em que a unidade vale mais do que a vitória imediata.
#
# Treinamento voltado à sabedoria prática e liderança moral. Crucial em conflitos sociais, decisões difíceis e mediação.
#
# ### Referências bíblicas
# - ¹⁹ Ouve agora minha voz, eu te aconselharei, e Deus será contigo. Sê tu pelo povo diante de Deus, e leva tu as causas a Deus;
# ²⁰ E declara-lhes os estatutos e as leis, e faze-lhes saber o caminho em que devem andar, e a obra que devem fazer. (Êxodo 18:19-20, ACF)
# - ¹⁴ Não havendo sábios conselhos, o povo cai, mas na multidão de conselhos há segurança. (Provérbios 11:14, ACF)
# 1 Reis 12:6-8.
# - ⁶ E teve o rei Roboão conselho com os anciãos que estiveram na presença de Salomão, seu pai, quando este ainda vivia, dizendo: Como aconselhais vós que se responda a este povo?
# ⁷ E eles lhe falaram, dizendo: Se hoje fores servo deste povo, e o servires, e respondendo-lhe, lhe falares boas palavras, todos os dias serão teus servos. (1 Reis 12:6-7, ACF)
#
# ### Função
# Orientar, julgar, aconselhar, resolver conflitos e sustentar a coesão do grupo.
# Voltado em sabedoria, decisão, unidade.
#
# ### Atributos
# +SAB, +PRS, +INT.

# %% [markdown]
# ## Artesão
#
# Os artesãos são os que transformam matéria bruta em provisão, beleza e utilidade. No deserto e na terra prometida, eles sustentam o povo com mãos firmes, preparando tendas, instrumentos, armas, utensílios e obras santas. Seu chamado lembra Bezalel e Aoliabe, capacitados por Deus para servir com excelência.
#
# São cruciais para fabricação, reparo, criação de objetos e estruturas.
#
# ### Referências bíblicas
# - ¹ Depois falou o Senhor a Moisés, dizendo:
# ² Eis que eu tenho chamado por nome a Bezalel, o filho de Uri, filho de Hur, da tribo de Judá,
# ³ E o enchi do Espírito de Deus, de sabedoria, e de entendimento, e de conhecimento, em todo o lavor,
# ⁴ Para elaborar projetos, e trabalhar em ouro, em prata, e em cobre,
# ⁵ E em lapidar pedras para engastar, e em entalhes de madeira, para trabalhar em todo o lavor.
# ⁶ E eis que eu tenho posto com ele a Aoliabe, o filho de Aisamaque, da tribo de Dã, e tenho dado sabedoria ao coração de todos aqueles que são hábeis, para que façam tudo o que te tenho ordenado. (Êxodo 31:1-6, ACF)
# - ¹⁴ Era ele filho de uma mulher viúva, da tribo de Naftali, e fora seu pai um homem de Tiro, que trabalhava em cobre; e era cheio de sabedoria, e de entendimento, e de conhecimento para fazer toda a obra de cobre; este veio ao rei Salomão, e fez toda a sua obra. (1 Reis 7:14, ACF)
#
# ### Função
# Fabricar, consertar, erguer tendas, preparar instrumentos e manter recursos.
#
# ### Atributos
# +FOR, +AGI, +INT.

# %% [markdown]
# ## Guerreiro
#
# Os guerreiros surgem quando o povo precisa resistir a inimigos, defender territórios e responder a ameaças. Na Bíblia, eles não são apenas combatentes: são homens de coragem, disciplina e, quando fiéis, instrumentos da libertação de Deus. A força do guerreiro não está só no braço, mas em sua disposição de obedecer mesmo sob risco.
#
# Treinamento voltado para combate, defesa de aliados, avanço sob risco.
#
# ### Referências bíblicas
# - ³ O Senhor é homem de guerra; o Senhor é o seu nome. (Êxodo 15:3, ACF)
# - ¹² Então o anjo do Senhor lhe apareceu, e lhe disse: O Senhor é contigo, homem valoroso.
# ¹³ Mas Gideão lhe respondeu: Ai, Senhor meu, se o Senhor é conosco, por que tudo isto nos sobreveio? E que é feito de todas as suas maravilhas que nossos pais nos contaram, dizendo: Não nos fez o Senhor subir do Egito? Porém agora o Senhor nos desamparou, e nos deu nas mãos dos midianitas.
# ¹⁴ Então o Senhor olhou para ele, e disse: Vai nesta tua força, e livrarás a Israel das mãos dos midianitas; porventura não te enviei eu?
# ¹⁵ E ele lhe disse: Ai, Senhor meu, com que livrarei a Israel? Eis que a minha família é a mais pobre em Manassés, e eu o menor na casa de meu pai.
# ¹⁶ E o Senhor lhe disse: Porquanto eu hei de ser contigo, tu ferirás aos midianitas como se fossem um só homem. (Juízes 6:12-16, ACF)
# - ⁴⁵ Davi, porém, disse ao filisteu: Tu vens a mim com espada, e com lança, e com escudo; porém eu venho a ti em nome do Senhor dos Exércitos, o Deus dos exércitos de Israel, a quem tens afrontado.
# ⁴⁶ Hoje mesmo o Senhor te entregará na minha mão, e ferir-te-ei, e tirar-te-ei a cabeça, e os corpos do arraial dos filisteus darei hoje mesmo às aves do céu e às feras da terra; e toda a terra saberá que há Deus em Israel;
# ⁴⁷ E saberá toda esta congregação que o Senhor salva, não com espada, nem com lança; porque do Senhor é a guerra, e ele vos entregará na nossa mão. (1 Samuel 17:45-47, ACF)
#
# ### Função
# Proteger o povo, escoltar, resistir a ameaças e enfrentar inimigos.
#
# ### Atributos
# +FOR, +AGI, +VGR.

# %% [markdown]
# ## Guardião
#
# Os guardiões são sentinelas, protetores e homens de vigia. Eles ficam nas portas, acompanham caravanas, protegem famílias e se colocam entre o perigo e o povo. Em tempos bíblicos, proteger era uma forma de fidelidade, pois cuidar dos vulneráveis era parte da justiça de Deus.
#
# Treinamento de proteção, vigilância, cuidado, escolta, guarda, defesa de acampamento e vigília.
#
# ### Referências bíblicas
# - ⁹ Porém nós oramos ao nosso Deus e pusemos uma guarda contra eles, de dia e de noite, por causa deles. (Neemias 4:9, ACF)
# - ¹ Se o Senhor não edificar a casa, em vão trabalham os que a edificam; se o Senhor não guardar a cidade, em vão vigia a sentinela. (Salmos 127:1, ACF)
# - ¹⁷ E foram porteiros: Salum, Acube, Talmom, Aimã, e seus irmãos, cujo chefe era Salum.
# ¹⁸ E até aquele tempo estavam de guarda à porta do rei, do lado do oriente; estes foram os porteiros dos arraiais dos filhos de Levi.
# ¹⁹ E Salum, filho de Coré, filho de Ebiasafe, filho de Corá, e seus irmãos da casa de seu pai, os coraítas, tinham cargo da obra do ministério, e eram guardas das portas do tabernáculo, como seus pais foram responsáveis pelo arraial do Senhor, e guardas da entrada.
# ²⁰ Fineias, filho de Eleazar, antes era líder entre eles; e o Senhor era com ele.
# ²¹ E Zacarias, filho de Meselemias, porteiro da entrada da tenda da congregação.
# ²² Todos estes, escolhidos para serem guardas das portas, foram duzentos e doze; e foram estes, segundo as suas aldeias, postos em suas genealogias; e Davi e Samuel, o vidente, os constituíram nos seus respectivos cargos. (1 Crônicas 9:17-22, ACF)
#
#
# ### Função
# Defender rotas, acampamentos, portas, crianças e bens.
#
# ###Atributos
# +FOR, +VGR, +SAB.

# %% [markdown]
# ## Levita
#
# Os levitas foram separados entre as tribos para o serviço santo. Eles carregavam o tabernáculo, cuidavam dos utensílios, auxiliavam os sacerdotes, ensinavam a Lei e sustentavam a ordem do culto. Sua história mostra que servir a Deus exige reverência, fidelidade e disposição para tarefas visíveis e invisíveis.
#
# Treinamento de serviço sagrado, ensino e cuidado com as coisas de Deus, ensino da Lei, adoração, organização do culto, cuidado espiritual.
#
# ### Referências bíblicas
# - ⁵ E falou o Senhor a Moisés, dizendo:
# ⁶ Faze chegar a tribo de Levi, e põe-na diante de Arão, o sacerdote, para que o sirvam,
# ⁷ E tenham cuidado da sua guarda, e da guarda de toda a congregação, diante da tenda da congregação, para administrar o ministério do tabernáculo.
# ⁸ E tenham cuidado de todos os utensílios da tenda da congregação, e da guarda dos filhos de Israel, para administrar o ministério do tabernáculo.
# ⁹ Darás, pois, os levitas a Arão e a seus filhos; dentre os filhos de Israel lhes são dados em dádiva.
# ¹⁰ Mas a Arão e a seus filhos ordenarás que guardem o seu sacerdócio, e o estranho que se chegar morrerá. (Números 3:5-10, ACF)
#
# - ¹⁴ E separarás os levitas do meio dos filhos de Israel, para que os levitas sejam meus.
# ¹⁵ E depois os levitas entrarão para fazerem o serviço da tenda da congregação; e tu os purificarás, e por oferta movida os oferecerás.
# ¹⁶ Porquanto eles, dentre os filhos de Israel, me são dados; em lugar de todo aquele que abre a madre, do primogênito de cada um dos filhos de Israel, para mim os tenho tomado.
# ¹⁷ Porque meu é todo o primogênito entre os filhos de Israel, entre os homens e entre os animais; no dia em que, na terra do Egito, feri a todo o primogênito, os santifiquei para mim.
# ¹⁸ E tomei os levitas em lugar de todo o primogênito entre os filhos de Israel.
# ¹⁹ E os levitas, dados a Arão e a seus filhos, dentre os filhos de Israel, tenho dado para ministrarem o ministério dos filhos de Israel na tenda da congregação e para fazer expiação pelos filhos de Israel, para que não haja praga entre os filhos de Israel, chegando-se os filhos de Israel ao santuário. (Números 8:14-19, ACF)
# - ⁸ E de Levi disse: Teu Tumim e teu Urim são para o teu amado, que tu provaste em Massá, com quem contendeste junto às águas de Meribá.
# ⁹ Aquele que disse a seu pai, e à sua mãe: Nunca os vi; e não conheceu a seus irmãos, e não estimou a seus filhos; pois guardaram a tua palavra e observaram a tua aliança.
# ¹⁰ Ensinaram os teus juízos a Jacó, e a tua lei a Israel; puseram incenso no teu nariz, e o holocausto sobre o teu altar. (Deuteronômio 33:8-10, ACF)
#
# ### Função
# Ensinar a Lei, conduzir cânticos, cuidar do culto, proteger a santidade e servir ao povo.
#
# ### Atributos
# +SAB, +INT, +PRS.

# %% [markdown]
# ## Mensageiro
#
# Os mensageiros atravessam distâncias levando palavras que podem mudar destinos. Em Israel, anunciar uma decisão, chamar à guerra, pedir socorro ou transmitir uma ordem era uma tarefa séria e às vezes perigosa. Seu valor está na rapidez, clareza e fidelidade à missão recebida.
#
# Treinamento focado em deslocamento, comunicação, diplomacia, missões.
#
# ### Referências bíblicas
# - ²² E prosseguiu Aimaás, filho de Zadoque, e disse a Joabe: Seja o que for deixa-me também correr após Cusi. E disse Joabe: Para que agora correrias tu, meu filho, pois não tens mensagem conveniente?
# ²³ Seja o que for, disse Aimaás, correrei. E Joabe lhe disse: Corre. E Aimaás correu pelo caminho da planície, e passou a Cusi.
# ²⁴ E Davi estava assentado entre as duas portas; e a sentinela subiu ao terraço da porta junto ao muro; e levantou os olhos, e olhou, e eis que um homem corria só.
# ²⁵ Gritou, pois, a sentinela, e o disse ao rei. E o rei respondeu: Se vem só, há novas em sua boca. E vinha andando e chegando.
# ²⁶ Então viu a sentinela outro homem que corria, e a sentinela gritou ao porteiro, e disse: Eis que lá vem outro homem correndo só. Então disse o rei: Também traz este novas.
# ²⁷ Disse mais a sentinela: Vejo o correr do primeiro, que parece ser o correr de Aimaás, filho de Zadoque. Então disse o rei: Este é homem de bem, e virá com boas novas.
# ²⁸ Gritou, pois, Aimaás, e disse ao rei: Paz. E inclinou-se ao rei com o rosto em terra, e disse: Bendito seja o Senhor, teu Deus, que entregou os homens que levantaram a mão contra o rei meu senhor. (2 Samuel 18:22-28, ACF)
# - ¹³ Como o frio da neve no tempo da sega, assim é o mensageiro fiel para com os que o enviam; porque refresca a alma dos seus senhores. (Provérbios 25:13, ACF)
# - ⁷ Quão formosos são, sobre os montes, os pés do que anuncia as boas novas, que faz ouvir a paz, do que anuncia o bem, que faz ouvir a salvação, do que diz a Sião: O teu Deus reina! (Isaías 52:7, ACF)
#
# ### Função
# levar recados, negociar, anunciar decisões e atravessar territórios.
#
# ### Atributos
# +AGI, +SAB, +PRS.

# %% [markdown]
# ## Pastor Nômade
#
# O pastor nômade conhece trilhas, fontes, sinais do tempo e o ritmo da vida em movimento. Essa vocação aparece desde os patriarcas e se torna imagem central da dependência de Deus: guiar, cuidar e sobreviver sem segurança permanente. O pastor aprende a confiar no Senhor enquanto conduz o rebanho por lugares incertos.
#
# Treinamento voltado à vida em movimento, cuidado com rebanhos e sobrevivência. Consegue buscar saídas no deserto, buscar abrigos, encontrar rotas.
#
# ### Referências bíblicas
# - ² E era Abrão muito rico em gado, em prata e em ouro.
# ³ E fez as suas jornadas do sul até Betel, até ao lugar onde a princípio estivera a sua tenda, entre Betel e Ai; (Gênesis 13:2,3, ACF)
# - ³⁸ Estes vinte anos eu estive contigo; as tuas ovelhas e as tuas cabras nunca abortaram, e não comi os carneiros do teu rebanho.
# ³⁹ Não te trouxe eu o despedaçado; eu o pagava; o furtado de dia e o furtado de noite da minha mão o requerias.
# ⁴⁰ Estava eu assim: De dia me consumia o calor, e de noite a geada; e o meu sono fugiu dos meus olhos. (Gênesis 31:38-40, ACF)
# - ¹ O Senhor é o meu pastor, nada me faltará.
# ² Deitar-me faz em verdes pastos, guia-me mansamente a águas tranquilas.
# ³ Refrigera a minha alma; guia-me pelas veredas da justiça por amor do seu nome.
# ⁴ Ainda que eu andasse pelo vale da sombra da morte, não temeria mal algum, porque tu estás comigo; a tua vara e o teu cajado me consolam. (Salmos 23:1-4, ACF)
#
# ### Função
# Conduzir animais, localizar recursos, viver em travessia e conhecer o território.
#
# ### Atributos
# +AGI, +VGR, +SAB.

# %% [markdown]
# ## Profeta
# Os profetas não surgem para agradar, mas para chamar o povo de volta à fidelidade. Eles confrontam o pecado, anunciam juízo, trazem esperança e lembram que Deus fala, guia e corrige sua aliança. O profeta carrega a tensão de ser ouvido por poucos e rejeitado por muitos, mas continua porque foi chamado.
#
# Treinamento de escuta, denúncia e chamado à fidelidade. Ele costuma chamar ao arrependimento, anunciar perigo e interpretar sinais.
#
# ### Referências bíblicas
# - ¹⁸ Eis lhes suscitarei um profeta do meio de seus irmãos, como tu, e porei as minhas palavras na sua boca, e ele lhes falará tudo o que eu lhe ordenar.
# ¹⁹ E será que qualquer que não ouvir as minhas palavras, que ele falar em meu nome, eu o requererei dele. (Deuteronômio 18:18-19, ACF)
# - ¹⁹ E crescia Samuel, e o Senhor era com ele, e nenhuma de todas as suas palavras deixou cair em terra.
# ²⁰ E todo o Israel, desde Dã até Berseba, conheceu que Samuel estava confirmado por profeta do Senhor.
# ²¹ E continuou o Senhor a aparecer em Siló; porquanto o Senhor se manifestava a Samuel em Siló pela palavra do Senhor. (1 Samuel 3:19-21, ACF)
# - ⁴ Assim veio a mim a palavra do Senhor, dizendo:
# ⁵ Antes que te formasse no ventre te conheci, e antes que saísses da madre, te santifiquei; às nações te dei por profeta.
# ⁶ Então disse eu: Ah, Senhor Deus! Eis que não sei falar; porque ainda sou um menino.
# ⁷ Mas o Senhor me disse: Não digas: Eu sou um menino; porque a todos a quem eu te enviar, irás; e tudo quanto te mandar, falarás.
# ⁸ Não temas diante deles; porque estou contigo para te livrar, diz o Senhor.
# ⁹ E estendeu o Senhor a sua mão, e tocou-me na boca; e disse-me o Senhor: Eis que ponho as minhas palavras na tua boca; (Jeremias 1:4-9, ACF)
#
# ### Função
# Falar em nome de Deus, confrontar pecado, exortar, consolar e chamar o povo de volta à aliança.
#
# ### Atributos
# +VGR, +SAB, +PRS.

# %% [markdown]
# ## Sacerdote
#
# Os sacerdotes foram chamados para mediar o culto, ensinar pureza, oferecer sacrifícios e interceder pelo povo. No sistema bíblico, sua função era manter a santidade diante de Deus e ajudar Israel a viver em reverência. O sacerdote representa o cuidado espiritual, a restauração e a responsabilidade de aproximar o povo da presença divina.
#
# Treinamento de mediação espiritual, santidade e intercessão. É pertio em ritos, cura, conselho espiritual, restauração da comunidade.
#
# ### Referências bíblicas
# - 1 Depois tu farás chegar a ti teu irmão Arão, e seus filhos com ele, do meio dos filhos de Israel, para me administrarem o ofício sacerdotal; a saber: Arão, Nadabe, e Abiú, Eleazar e Itamar, os filhos de Arão. (Êxodo 28:1, ACF);
# - ⁹ Não bebereis vinho nem bebida forte, nem tu nem teus filhos contigo, quando entrardes na tenda da congregação, para que não morrais; estatuto perpétuo será isso entre as vossas gerações;
# ¹⁰ E para fazer diferença entre o santo e o profano e entre o imundo e o limpo,
# ¹¹ E para ensinar aos filhos de Israel todos os estatutos que o Senhor lhes tem falado por meio de Moisés. (Levítico 10:9-11, ACF)
# - ²² E falou o Senhor a Moisés, dizendo:
# ²³ Fala a Arão, e a seus filhos dizendo: Assim abençoareis os filhos de Israel, dizendo-lhes:
# ²⁴ O Senhor te abençoe e te guarde;
# ²⁵ O Senhor faça resplandecer o seu rosto sobre ti, e tenha misericórdia de ti;
# ²⁶ O Senhor sobre ti levante o seu rosto e te dê a paz.
# ²⁷ Assim porão o meu nome sobre os filhos de Israel, e eu os abençoarei. (Números 6:22-27, ACF)
#
# ### Função
# Oferecer orientação espiritual, ensinar pureza, interceder e sustentar a vida de culto.
#
# ### Atributos
# +FOR, +INT, +PRS.

# %% [markdown]
# #Perícias
#
# As perícias representam o que o personagem aprendeu na prática. Enquanto as habilidades refletem potencial natural, as perícias mostram treinamento, experiência e especialização.
#
# A perícia pode ter 4 graduações:
# - Impossível: não pode realizar este teste;
# - Desvantagem: Realiza teste com 1 dado comum a menos
# - Normal
# - Vantagem: Realiza teste com 1 dado comum a mais
#
# Quando um personagem tenta fazer algo arriscado, o mestre pode pedir um teste de perícia apropriado. Se o personagem tiver vantagem naquela perícia, ele rola com maior chance de sucesso.

# %% [markdown]
# ## Vantagens em Perícias
# Vantagem em perícia significa que o personagem é especialmente competente naquela área. No jogo, isso pode ser representado por:
#
# rolar dois dados e usar o melhor resultado;
#
# receber bônus narrativo;
#
# reduzir dificuldade em situações compatíveis;
#
# obter melhor posição em disputas sociais ou físicas.
#
# Um personagem pode receber vantagem em perícia por três fontes:
#
# - Atributo;
#
# - Povo;
#
# - Classe.
#
# - Dádiva (talento)
#
# Essas fontes podem se acumular se o sistema da campanha permitir. Caso duas ou mais fontes concedam vantagem na mesma perícia, o mestre pode optar por:
#
# - manter apenas uma vantagem;
#
# - transformar o excesso em benefício narrativo;
#
# - ou conceder um efeito especial adicional, se desejar mais destaque ao personagem.

# %% [markdown]
# ## Estrutura das perícias
# No seu sistema simplificado, cada perícia representa um tipo de ação recorrente. A ideia é que o mestre peça um teste quando:
#
# - houver risco real de falha;
#
# - a ação for importante para a cena;
#
# - o resultado mudar a história;
#
# - houver oposição ativa de outra criatura ou personagem.
#
# Em geral:
#
# - **Sucesso**: o personagem consegue fazer o que tentou.
#
# - **Sucesso alto**: consegue com vantagem narrativa, rapidez ou estilo.
#
# - **Falha**: não consegue, ou consegue com custo.
#
# - **Falha crítica**: pode gerar barulho, atraso, ferimento, perda de recurso ou suspeita.

# %% [markdown]
# ## Lista de Perícias
#
# ### Força
# - Escalar: subir, descer e atravessar superfícies verticais ou inclinadas usando força corporal, equilíbrio e firmeza de pegada.
# - Luta: combate corpo a corpo, imobilizações, empurrões e confrontos físicos diretos.
#
# - Trabalho: esforço pesado, carregar objetos, abrir caminho, construir, quebrar obstáculos.
#
# ### Agilidade
# - Arquearia: disparos à distância, mira precisa, uso de arco, funda ou armas de arremesso.
#
# - Furtividade: mover-se sem ser visto, esconder-se, agir em silêncio, infiltração.
#
# - Acrobacia: saltos, equilíbrio, quedas, esquivas e movimentos corporais difíceis.
#
# ### Vigor
# - Resistência: suportar dor, calor, fome, sede, doença, cansaço e esforço prolongado.
#
# - Sobrevivência: encontrar água, comida e abrigo; seguir trilhas; viver em ambiente hostil.
#
#
# ### Intelecto
# - Teologia: fé, ritos, mandamentos, pureza, culto, símbolos sagrados e doutrinas.
#
# - História: povos antigos, genealogias, eventos passados, cidades, reis e tratados.
#
# - Ofício: fabricar, consertar, construir e avaliar qualidade de objetos e estruturas.
#
# ### Sabedoria
# - Cura: primeiros socorros, tratamento de ferimentos leves, estabilidade de feridos e cuidados básicos.
#
# - Percepção: notar detalhes, sons, pistas, ameaças e coisas escondidas, perceber mentiras, intenções, tensão emocional e perigo social.
#
# - Vontade: resistir a medo, tentação, pressão espiritual, intimidação e manipulação.
#
# ### Presença
# - Diplomacia: conversar, negociar, acalmar, persuadir e resolver conflitos.
#
# - Liderança: comandar, inspirar, organizar grupos e manter disciplina.
#
# - Performance: cantar, recitar, discursar, entreter e transmitir emoção.
#
# | Perícia       | 1 Direção                   | 2 Direções                    | 3 Direções                           | 1 Complicação               | 2 Complicações                 | 3 Complicações                      |
# | ------------- | --------------------------- | ----------------------------- | ------------------------------------ | --------------------------- | ------------------------------ | ----------------------------------- |
# | Acrobacia     | Pega impulso favorável.     | Supera obstáculo com estilo.  | Muda o ritmo da cena.                | Quase cai.                  | Cai ou se expõe.               | Sofre lesão leve.                   |
# | Arquearia     | Vento e ângulo ajudam.      | Acerto preciso.               | Disparo muda a cena.                 | Chama atenção.              | Perde a posição.               | Revela o grupo.                     |
# | Cura    | Alivia uma condição leve. | Estabiliza e reduz a condição. | Remove a condição ou impede agravamento. | O cuidado é lento. | A condição persiste. | O tratamento piora a situação. |
# | Diplomacia    | Frase certa reduz tensão.   | Abre conversa.                | Faz o grupo negociar.                | Diálogo frio.               | Ofensa ou dívida social.       | Piora relações.                     |
# | Furtividade   | Encontra cobertura.         | Passa sem ser notado.         | Vira vantagem tática.                | Quase é visto.              | Deixa rastro.                  | Compromete a missão.                |
# | História      | Recorda um fato útil.       | Liga o fato ao presente.      | Oferece solução histórica.           | Memória incompleta.         | Confunde dados.                | Decide com base errada.             |
# | Liderança     | Indica quem age primeiro.   | Dá foco e ordem.              | Muda o rumo do grupo.                | Obediência sem ânimo.       | Contestação interna.           | Gera divisão.                       |
# | Luta          | Abre a guarda.              | Dá golpe limpo.               | Domina o corpo a corpo.              | Acerta, mas abre defesa.    | Troca arriscada.               | Arma ou defesa comprometida.        |
# | Ofício        | Faz algo funcionar.         | Repara ou produz bem.         | Cria solução excelente.              | Fica frágil.                | Precisa refazer.               | Gera atraso grave.                  |
# | Percepção     | Nota detalhe útil, ou sente que algo está errado.          | Vê pista importante, ou percebe intenção oculta.          | Entende a cena antes da virada, ou enxerga o problema real.      | Revela sua posição ou sinal confuso .        | Perde a vantagem, ou interpreta cedo demais.            | Custo alto pela demora, ou erro grave por confiança excessiva.              |
# | Performance   | Chama a atenção certa.      | Emociona ou convence.         | Muda a atmosfera.                    | Sucesso com ruído.          | Público reage mal.             | Reforça imagem negativa.            |
# | Resistência   | Ganha fôlego.               | Suporta dor ou impacto.       | Aguenta condição severa.             | Fica exausto.               | Pede pausa.                    | Penalidade física duradoura.        |
# | Sobrevivência | Encontra água ou abrigo.    | Lê o terreno.                 | Guia o grupo com precisão.           | Gasta tempo ou energia.     | Escolhe rota ruim.             | O ambiente cobra alto preço.        |
# | Teologia      | Lembra um princípio útil.   | Aponta a leitura mais segura. | Revela o sentido espiritual da cena. | Gera debate ou resistência. | Alguém questiona a autoridade. | A aplicação causa divisão.          |
# | Trabalho      | Organiza o esforço.         | Completa com eficiência.      | Rende acima do esperado.             | Faz com desgaste.           | Cobra preço físico.            | Atrasa o grupo.                     |
# | Tratamento | Estabiliza uma condição leve. | Reduz ou corrige a condição. | Remove a condição ou impede a piora. | O cuidado atrasa. | A condição volta ou se agrava. | O procedimento falha e cobra custo alto. |
# | Vontade       | Firmeza contra medo.        | Clareza de propósito.         | Inspira os outros.                   | Fica abalado.               | Perde parte do controle.       | A pressão marca a cena.             |

# %% [markdown]
# ## Acrobacia (Agilidade)
#
# Use para equilíbrio, saltos, rolamentos, escapar de agarrões e passar por lugares estreitos ou instáveis.
#
# Também serve para:
#
# - atravessar pedras, muros baixos ou telhados;
#
# - escapar de queda;
#
# - passar por terreno difícil com rapidez;
#
# - fazer manobras corporais em fuga.
#
# Exemplo: um mensageiro corre por uma encosta de pedras e precisa saltar entre duas saliências.

# %% [markdown]
# ## Arquearia (Agilidade)
#
# Use para atacar com armas de projétil e para ações que exijam mira à distância. Inclui arco, funda, dardo arremessado, lança em arremesso e, se existir no cenário, besta.
#
# Também serve para:
#
# - tiro preciso;
#
# - acertar alvos pequenos;
#
# - disparar montado;
#
# - manter pressão à distância.
#
# Exemplo: um midianita atira uma flecha em um animal antes que ele fuja.

# %% [markdown]
# ## Cura (Sabedoria)
# Use para primeiros socorros, tratamento de feridas, estabilizar feridos e lidar com enfermidades simples.
#
# Também serve para:
#
# - estancar sangramento;
#
# - fazer curativos;
#
# - tratar febre leve;
#
# - cuidar de exaustão;
#
# - aplicar ervas e remédios simples.
#
# Exemplo: após uma escaramuça, um levita tenta salvar um ferido antes que ele piore.

# %% [markdown]
# ## Diplomacia (Presença)
# Use para negociar, convencer, apaziguar conflitos, pedir favores e falar com autoridade respeitosa.
#
# Também serve para:
#
# - tratar com povos estrangeiros;
#
# - resolver disputas;
#
# - obter passagem segura;
#
# - fazer acordos;
#
# - acalmar uma multidão.
#
# Exemplo: um emissário pede aos edomitas permissão para atravessar uma estrada.

# %% [markdown]
# ## Escalar (Força)
#
# Escalar (FOR) representa subir, descer e atravessar superfícies verticais ou inclinadas usando força corporal, equilíbrio e firmeza de pegada.
#
# ### Descrição
# Essa perícia cobre muros, árvores, penhascos, telhados, ruínas, cordas grossas e outras superfícies que exigem sustentar o próprio peso com esforço físico. Ela também serve para movimentos difíceis em combate, fuga, exploração e infiltração, quando o personagem precisa vencer altura ou irregularidade.
#
# ### Usos comuns
# Use Escalar quando o personagem precisar:
# - subir com rapidez.
# - descer sem cair.
# - atravessar uma parede ou obstáculo alto.
# - carregar peso durante a subida.
# - ajudar outro personagem a subir ou descer.

# %% [markdown]
# ## Furtividade (Agilidade)
#
# Use para se esconder, se mover sem ser notado, aproximar-se em silêncio e evitar atenção.
#
# Também serve para:
#
# - espionagem;
#
# - entrar em campo inimigo;
#
# - seguir alguém sem ser visto;
#
# - esconder objetos ou pessoas;
#
# - esperar em emboscada.
#
# Exemplo: um espia cananeu tenta entrar no acampamento israelita sem ser visto.

# %% [markdown]
# ## História (Intelecto)
# Use para lembrar acontecimentos antigos, genealogias, guerras, alianças, reis, cidades e tradições dos povos.
#
# Também serve para:
#
# - reconhecer um povo pela origem;
#
# - lembrar rotas e impérios;
#
# - saber de batalhas passadas;
#
# - entender rivalidades antigas;
#
# - identificar ruínas e nomes antigos.
#
# Exemplo: um ancião ouve o nome de uma cidade e lembra que ela já foi fortificada por um rei amorreu.

# %% [markdown]
# ## Luta (Força)
# Use para combate corpo a corpo e agressão física direta. Isso inclui socos, quedas, golpes com espada, lança, cajado, clava e armas improvisadas de perto.
#
# Também serve para:
#
# - segurar alguém à força;
#
# - abrir uma porta à força;
#
# - empurrar, derrubar ou imobilizar;
#
# - wrestling, briga, contenção física.
#
# Exemplo: um hebreu tenta derrubar um filisteu no chão durante uma emboscada.

# %% [markdown]
# ## Liderança (Presença)
# Use para comandar, inspirar, coordenar grupo, manter moral e organizar pessoas sob pressão.
#
# Também serve para:
#
# - dar ordens em combate;
#
# - conduzir caravanas;
#
# - manter disciplina;
#
# - levantar ânimo;
#
# - unir clãs e famílias.
#
# Exemplo: um chefe tribal precisa manter o povo calmo durante uma crise de escassez.

# %% [markdown]
# ## Ofício (Intelecto)
# Use para fabricar, reparar e construir coisas. É a perícia dos agricultura, artesãos, comércio, ferreiros, carpinteiros, tecelões, curtidores, costura, marcenaria, arquitetura, navegação e oleiros.
#
# Também serve para:
#
# - fazer ferramentas e armas simples;
#
# - reparar carroças, tendas e utensílios;
#
# - trabalhar madeira, metal, couro e tecido;
#
# - montar estruturas;
#
# - avaliar qualidade de produção.
#
# Exemplo: um artesão precisa reconstruir uma peça do santuário transportável.

# %% [markdown]
# ## Percepção (Sabedoria)
# Use para notar detalhes no ambiente. Serve para ver, ouvir, sentir cheiro, perceber movimento e detectar perigo, perceber intenção, mentira, tensão social e emoção escondida.
#
# Também serve para:
#
# - notar emboscadas;
#
# - achar pistas no chão;
#
# - perceber um olhar suspeito;
#
# - ouvir alguém se aproximando;
#
# - detectar algo escondido;
#
# - saber se alguém está mentindo;
#
# - sentir traição;
#
# - entender clima de uma conversa;
#
# - perceber medo ou culpa;
#
# - ler postura e comportamento.
#
# Exemplo: um sentinela nota movimento entre pedras perto do acampamento.
#
# Exemplo: um juiz de Israel desconfia que um visitante não veio em paz.

# %% [markdown]
# ## Performance (Presença)
#
# Use para cantar, tocar, recitar, contar histórias, discursar com impacto e entreter.
#
# Também serve para:
#
# - louvor;
#
# - poesia;
#
# - proclamações públicas;
#
# - cerimônias;
#
# - acalmar crianças e grupos.
#
# Exemplo: um levita canta um cântico para fortalecer o espírito do povo após uma travessia difícil.

# %% [markdown]
# ## Resistência (Vigor)
#
# Use para suportar cansaço, fome, sede, calor, frio, venenos, doença e marcha longa.
#
# Também serve para:
#
# - correr por muito tempo;
#
# - aguentar pancadas;
#
# - resistir a dor;
#
# - continuar consciente após ferimento;
#
# - ficar em guarda por horas.
#
# Exemplo: a caravana precisa atravessar o deserto sem água suficiente.

# %% [markdown]
# ## Sobrevivência (Vigor)
#
# Use para viver e se orientar em ambientes hostis. É a perícia do deserto, da mata, da estrada e do acampamento.
#
# Também serve para:
#
# - encontrar água, comida e abrigo;
#
# - seguir rastros;
#
# - reconhecer clima e direção;
#
# - montar acampamento seguro;
#
# - perceber sinais de perigo natural.
#
# - fazer plantações
#
# Exemplo: um líder tribal procura um caminho seguro para uma rota de pastoreio.

# %% [markdown]
# ## Teologia (Intelecto)
# Use para entender a fé, os ritos, as leis sagradas, os mandamentos, os cultos e a interpretação religiosa dos acontecimentos.
#
# Também serve para:
#
# - reconhecer heresias;
#
# - saber o sentido de festas e sacrifícios;
#
# - interpretar sinais espirituais;
#
# - conhecer sacerdócio e pureza ritual;
#
# - lembrar histórias sagradas.
#
# Exemplo: um sacerdote precisa decidir se um objeto pode entrar no tabernáculo.

# %% [markdown]
# ## Trabalho (Força)
# Use para esforço físico prolongado e tarefas pesadas. É a perícia de carregar, puxar, empurrar, erguer, cavar, cortar, construir e romper obstáculos.
#
# Também serve para:
#
# - mover pedra, madeira ou cargas;
#
# - escavar trincheiras;
#
# - abrir passagem;
#
# - montar acampamento pesado;
#
# - trabalho braçal repetitivo.
#
# Exemplo: um grupo precisa levantar um abrigo no deserto antes do anoitecer.

# %% [markdown]
# ## Tratamento (Vigor)
# Tratamento é a perícia usada para cuidar de ferimentos, aliviar condições e estabilizar o próprio corpo ou o de outra pessoa. Ela cobre primeiros socorros, contenção de sangramento, repouso orientado, aplicação de recursos simples, ajuste de postura, alívio de dor e procedimentos práticos para impedir que uma condição piore.
#
# O narrador pode usar Tratamento quando o personagem tenta se curar, reduzir uma condição, evitar agravamento, ou ajudar outro personagem a se recuperar. Em situações mais técnicas, longas ou delicadas, o narrador pode exigir Intelecto; em situações de atenção, discernimento e cuidado, pode exigir Sabedoria. Em cenas de esforço físico para suportar dor e continuar funcionando, o mestre pode combinar Tratamento com Vigor apenas se a ação for mais de resistência do corpo do que de aplicação de cuidado.

# %% [markdown]
# ## Vontade (Sabedoria)
# Use para resistir a medo, intimidação, tentação, manipulação, loucura, opressão espiritual e pressão moral.
#
# Também serve para:
#
# - não quebrar sob ameaça;
#
# - resistir a maldição ou encantamento;
#
# - manter a fé;
#
# - suportar visões aterradoras;
#
# - não ceder a suborno moral.
#
# Exemplo: um hebreu é pressionado a adorar um ídolo, mas tenta resistir.

# %% [markdown]
# ## Como o mestre pode pedir testes
# Uma forma simples de decidir:
#
# - Luta: conflito físico direto.
#
# - Trabalho: esforço braçal e construção.
#
# - Arquearia: ataque ou ação à distância.
#
# - Furtividade: esconder-se ou agir sem ser percebido.
#
# - Acrobacia: movimento difícil e controle corporal.
#
# - Resistência: suportar desgaste físico.
#
# - Sobrevivência: viver no ambiente e se orientar.
#
# - Cura: tratar feridos e doentes.
#
# - Teologia: assuntos sagrados, ritos e fé.
#
# - História: memória de povos, eventos e linhagens.
#
# - Ofício: fabricar e consertar.
#
# - Percepção: notar o que está acontecendo.
#
# - Intuição: ler pessoas e intenções.
#
# - Vontade: resistir psicologicamente ou espiritualmente.
#
# - Diplomacia: conversar, negociar e persuadir.
#
# - Liderança: comandar e inspirar.
#
# - Performance: expressar, recitar, cantar.

# %% [markdown]
# # Sistema de testes

# %% [markdown]
# ### ⬜ Dado comum
# O dado comum é um dado narrativo de 6 faces, usado em todos os testes do jogo. Em vez de números, ele apresenta símbolos que indicam sucesso, anulação, complicação e outros efeitos especiais.
#
#
# As faces do dado comum é:
#
# | Tipo                | Face | Efeito                                                   |
# | ------------------- | ---- | -------------------------------------------------------- |
# | Sucesso          | ⭐    | 1 sucesso                                                |
# | Anulação          | ❌    | 1 anulação  de sucesso                                              |
# | Anulação          | ❌    | 1 anulação de sucesso                                               |
# | Sucesso maior          | ☀️    | 2 sucessos                                               |
# | Dificuldade          | +🟥  | Adiciona 1 dado de dificuldade                           |
# | Fé          | +🟩  | Adiciona 1 dado de Fé                                    |

# %% [markdown]
# ### 🟥 Dado de dificuldade
# O dado de dificuldade representa pressão, risco, oposição, custo narrativo e desgaste. Ele surge como efeito de um teste com resultado de adicionar dadod e dificuldade.
#
# São as faces do dado de dificuldade:
#
# | Tipo                | Face | Efeito                                                   |
# | ------------------- | ---- | -------------------------------------------------------- |
# | Sem efeito |     | Nada acontece                                     |
# | Dado comum | +⬜    | Adiciona dado comum à rolagem                                     |
# | Complicação | ⚠️   | Aumenta o risco e efeito de Desvantagem   |
# | Anulação | ❌    | Anula 1 sucesso                                               |
# | Anulação + Complicação | ❌⚠️  | Efeitos de Anulação + Complicação                                 |
# | Desvantagem | ⛔    | Recebe 1 **marcador de desvantagem**|
#
# **Complicação** não anula sucesso, mas aumenta o custo da cena, prepara risco, atraso, exposição ou desgaste, e recebe um ⛔ **marcador de desvantagem** .
#
# **Marcador de desvantagem** ⛔ deve ser utilizado no momento que o narrador indicar.
#
# O narrador pode conceder dados de dificuldade quando houver ambiente hostil, oposição forte, escassez, doença, pressa, confusão, medo, terreno difícil ou perda de tempo ou rodada.

# %% [markdown]
# ### 🟩 Dado de fé
# O dado de Fé representa a intervenção favorável de Deus na narrativa. Ele não é controlado pelo personagem, mas recebido como resposta à fé, à obediência e ao momento dramático da história.
#
# São as faces do dado de fé:
#
# | Tipo                | Face | Efeito                                                   |
# | ------------------- | ---- | -------------------------------------------------------- |
# | Marcador de vantagem          | 🔵   | O jogador recebe 1 marcador de vantagem                  |
# | Direção          | 👉🏼 | Jogador recebe uma pista, ajuda inesperada       |
# | Proteção          | 🛡️  | Cancela 1 Complicação, dano ou Anulação                  |
# | Milagre raro          | 🪽   | Milagre raro, efeito extraordinário do Treinamento       |
# | Dado comum | +⬜    | Adiciona  dado comum à rolagem                                     |
# | Sem efeito |     | Nada acontece                                     |
#
#
# - 🔵 **Vantagem**: O jogador recebe um marcador de vantagem para utilizar à sua escolha durante a sessão.
#
# - 👉🏼 **Direção**: O narrador revela a melhor ação, pista ou decisão, surge uma ajuda inesperada, oportunidade ou caminho aberto.
#
# - 🛡️ **Proteção**: cancela uma ⚠️ Complicação, dano ou ❌ Anulação.
#
# - 🪽 **Milagre raro**: quando este símbolo aparece, o narrador interpreta um efeito extraordinário relacionado ao Treinamento do personagem. O efeito deve ser maior quanto mais símbolos 🪽 forem obtidos na rolagem. Um símbolo concede um benefício pontual; dois, um resultado relevante; três, uma mudança decisiva; quatro ou mais, um milagre excepcional.
#
# O dado de Fé pode aparecer quando o personagem manifesta confiança, obediência, oração, coragem ou fidelidade em situações decisivas.

# %% [markdown]
# ### Estrutura do teste
# Todo teste tem as seguntes etapas:
# 1. **Determinar tipo de teste**: se será normal, com vantagem ou desvantagem. O narrador determina se utilizará marcador de desvantagem e o jogador decide se utilizará vantagem.
#
# 2. **Rolagem do teste**
#
# 3. **Contabilizar os resultados**
#
# 4. **Resolver os efeitos colaterais**

# %% [markdown]
# #### 1} Determinando a base de teste
#
# Cada teste tem uma base que inform a quantidade básica de dados, conforme a coluna indicada no teste + dados bônus de nível.
#
# Neste momento o narrador pode solicitar que gaste marcador de desvantagem e o jogador pode utilizar marcador de vantagem. A quantidade de dados comuns adicionados é o saldo líquido dos marcadores.
#
# - Vantagem: +1 dado comum.
#
# - Desvantagem: -1 dado comum.
#
# - Treinamento: altos níveis de personagem dão acesso a dados de Fé desde a rolagem inicial.
#
# Nenhum teste deve cair abaixo de 2 dados, salvo em situações extremamente severas definidas pelo narrador.
#
# Marcadores de vantagem e desvantagem não se acumulam. Sempre vale apenas 1 marcador de cada tipo por vez.
#
# Contudo, um efeito de vantagem pode anular um de desvantagem. E vice-versa.
#
# ##### **Função dos marcadores**
# Existem distinções entre os tipos de marcadores:
#
# ##### Marcador de vantagem
# - Pode ser guardado para uma rolagem futura.
#
# - Só pode ser usado uma vez.
#
# - Não acumula com outro marcador igual.
#
# ##### Marcador de desvantagem
# - Deve ser aplicado quando o narrador julgar apropriado.
#
# - Também não acumula.
#
# - Pode ser usado para representar pressões persistentes da cena.

# %% [markdown]
# #### 2} Rolando os dados
#
# Quando houver rolagem de dados, algumas faces de dados pedem para adicionar novos dados. Sempre que ocorrer, role-os antes de encerrar a fase de rolagem de dados e agrupe-os por símbolos:
#
# - Sucessos
# - Anulações
# - Complicações
# - Proteções
# - Marcadores de vantagem
# - Marcadores de desvantagem
# - Fé

# %% [markdown]
# #### 3} Contabilizando o resultado líquido
#
# Nesta etapa, calculamos os saldos líquidos em jogo, fazendo as seguintes subtrações:
#
# - Sucesso x Anulação;
# - Complicação x Proteção;
# - Marcadores de vantagem x de desvantagem.

# %% [markdown]
# #### [editar] {4} Resolvendo os efeitos colaterais
#
# Isso evita discussão na hora de interpretar uma rolagem com muitos símbolos.
#
# ### Resultados colaterais
#
# | Perícia       | 1 Direção                   | 2 Direções                    | 3 Direções                           | 1 Complicação               | 2 Complicações                 | 3 Complicações                      |
# | ------------- | --------------------------- | ----------------------------- | ------------------------------------ | --------------------------- | ------------------------------ | ----------------------------------- |
# | Acrobacia     | Pega impulso favorável.     | Supera obstáculo com estilo.  | Muda o ritmo da cena.                | Quase cai.                  | Cai ou se expõe.               | Sofre lesão leve.                   |
# | Arquearia     | Vento e ângulo ajudam.      | Acerto preciso.               | Disparo muda a cena.                 | Chama atenção.              | Perde a posição.               | Revela o grupo.                     |
# | Diplomacia    | Frase certa reduz tensão.   | Abre conversa.                | Faz o grupo negociar.                | Diálogo frio.               | Ofensa ou dívida social.       | Piora relações.                     |
# | Furtividade   | Encontra cobertura.         | Passa sem ser notado.         | Vira vantagem tática.                | Quase é visto.              | Deixa rastro.                  | Compromete a missão.                |
# | História      | Recorda um fato útil.       | Liga o fato ao presente.      | Oferece solução histórica.           | Memória incompleta.         | Confunde dados.                | Decide com base errada.             |
# | Intuição      | Sente que algo está errado. | Percebe intenção oculta.      | Enxerga o problema real.             | Sinal confuso.              | Interpreta cedo demais.        | Erro grave por confiança excessiva. |
# | Liderança     | Indica quem age primeiro.   | Dá foco e ordem.              | Muda o rumo do grupo.                | Obediência sem ânimo.       | Contestação interna.           | Gera divisão.                       |
# | Luta          | Abre a guarda.              | Dá golpe limpo.               | Domina o corpo a corpo.              | Acerta, mas abre defesa.    | Troca arriscada.               | Arma ou defesa comprometida.        |
# | Ofício        | Faz algo funcionar.         | Repara ou produz bem.         | Cria solução excelente.              | Fica frágil.                | Precisa refazer.               | Gera atraso grave.                  |
# | Percepção     | Nota detalhe útil.          | Vê pista importante.          | Entende a cena antes da virada.      | Revela sua posição.         | Perde a vantagem.              | Custo alto pela demora.             |
# | Performance   | Chama a atenção certa.      | Emociona ou convence.         | Muda a atmosfera.                    | Sucesso com ruído.          | Público reage mal.             | Reforça imagem negativa.            |
# | Resistência   | Ganha fôlego.               | Suporta dor ou impacto.       | Aguenta condição severa.             | Fica exausto.               | Pede pausa.                    | Penalidade física duradoura.        |
# | Sobrevivência | Encontra água ou abrigo.    | Lê o terreno.                 | Guia o grupo com precisão.           | Gasta tempo ou energia.     | Escolhe rota ruim.             | O ambiente cobra alto preço.        |
# | Teologia      | Lembra um princípio útil.   | Aponta a leitura mais segura. | Revela o sentido espiritual da cena. | Gera debate ou resistência. | Alguém questiona a autoridade. | A aplicação causa divisão.          |
# | Trabalho      | Organiza o esforço.         | Completa com eficiência.      | Rende acima do esperado.             | Faz com desgaste.           | Cobra preço físico.            | Atrasa o grupo.                     |
# | Vontade       | Firmeza contra medo.        | Clareza de propósito.         | Inspira os outros.                   | Fica abalado.               | Perde parte do controle.       | A pressão marca a cena.             |
#
# 1 Direção: encontra boa pega, ritmo ou rota segura.
# 2 Direções: executa a subida com firmeza.
# 3 Direções: sobe com excelência e pode abrir caminho para outros.
# 1 Complicação: escorrega, faz barulho ou perde tempo.
# 2 Complicações: fica exposto, se cansa ou quase cai.
# 3 Complicações: sofre queda, ferimento ou falha grave �.
#
# ### Efeitos de Milagre raros
#
# O 🪽 Milagre raro terá efeitos mais forte conforme a quantidade de faces obtidas  cresce. Ele é escalado em quatro níveis:
#
# - 1 símbolo 🪽: milagre menor, útil e pontual.
#
# - 2 símbolos 🪽🪽: milagre relevante, muda a cena.
#
# - 3 símbolos 🪽🪽🪽: milagre forte, altera o rumo do conflito.
#
# - 4+ símbolos 🪽🪽🪽🪽: milagre excepcional, quase decisivo.
#
# #### **Conselheiro**
# **Tema**: sabedoria, paz, decisão.
#
# - 1 🪽: o personagem recebe clareza para aconselhar corretamente uma pessoa importante.
#
# - 2 🪽🪽: uma disputa é desarmada; duas partes aceitam conversar sem violência.
#
# - 3 🪽🪽🪽: surge uma solução inesperada que salva o grupo de uma crise social ou política.
#
# - 4+ 🪽🪽🪽🪽: o personagem inspira unidade duradoura; um grupo dividido muda de postura.
#
# #### **Artesão**
# **Tema**: solução prática, reparo, criação.
#
# - 1 🪽: um item importante é consertado de forma improvável.
#
# - 2 🪽🪽: o personagem improvisa uma ferramenta ou peça que resolve o problema imediato.
#
# - 3 🪽🪽🪽: uma obra ou reparo impossível à primeira vista é concluído em tempo crítico.
#
# - 4+ 🪽🪽🪽🪽: o trabalho feito resiste além do esperado, tornando-se símbolo de excelência e provisão.
#
# #### **Guerreiro**
# **Tema**: coragem, avanço, vitória.
#
# - 1 🪽: o personagem supera o medo e luta com firmeza.
#
# - 2 🪽🪽: um inimigo é derrotado ou forçado a recuar.
#
# - 3 🪽🪽🪽: o combate muda de rumo a favor do grupo.
#
# - 4+ 🪽🪽🪽🪽: o personagem vira o ponto de virada da batalha; a vitória se torna narrativa e moralmente marcante.
#
# #### **Guardião**
# **Tema**: proteção, vigilância, contenção.
#
# - 1 🪽: um aliado evita um golpe, queda ou armadilha.
#
# - 2 🪽🪽: o grupo encontra abrigo seguro ou posição defensável.
#
# - 3 🪽🪽🪽: uma ameaça é contida antes de causar dano maior.
#
# - 4+ 🪽🪽🪽🪽: o personagem protege um grupo inteiro de um desastre imediato, como emboscada, pânico ou ruptura defensiva.
#
# #### **Levita**
# **Tema**: serviço sagrado, ordem, adoração.
#
# - 1 🪽: o personagem restabelece reverência e concentração no ambiente sagrado.
#
# - 2 🪽🪽: um ato de culto ou cerimônia é realizado sem interrupção, mesmo sob pressão.
#
# - 3 🪽🪽🪽: um grupo inteiro é trazido de volta ao senso de santidade e propósito.
#
# - 4+ 🪽🪽🪽🪽: a presença do levita transforma a atmosfera da cena; medo e confusão dão lugar a paz e reverência.
#
# #### **Mensageiro**
# **Tema**: missão, caminho, comunicação.
#
# - 1 🪽: a mensagem chega sem ser interceptada.
#
# - 2 🪽🪽: o personagem encontra o caminho mais rápido e seguro.
#
# - 3 🪽🪽🪽: uma missão aparentemente perdida é concluída com êxito total.
#
# - 4+ 🪽🪽🪽🪽: a mensagem chega no momento exato e altera o destino de uma comunidade inteira.
#
# #### **Pastor nômade**
# **Tema**: rota, provisão, cuidado, travessia.
#
# - 1 🪽: o grupo encontra água, sombra ou abrigo.
#
# - 2 🪽🪽: o personagem localiza uma rota segura ou rebanho perdido.
#
# - 3 🪽🪽🪽: uma travessia hostil se torna viável graças à orientação correta.
#
# - 4+ 🪽🪽🪽🪽: o grupo inteiro atravessa uma situação impossível no deserto sem perdas significativas.
#
# #### **Profeta**
# **Tema**: verdade, revelação, confronto.
#
# - 1 🪽: o personagem percebe a raiz espiritual de um problema.
#
# - 2 🪽🪽: uma pessoa ou grupo é confrontado com a verdade no momento certo.
#
# - 3 🪽🪽🪽: o aviso profético evita uma tragédia maior.
#
# - 4+ 🪽🪽🪽🪽: a palavra profética muda o curso de um evento coletivo; arrependimento, livramento ou restauração começam ali.
#
# #### **Sacerdote**
# **Tema**: intercessão, purificação, restauração.
#
# - 1 🪽: o personagem traz paz ao coração de alguém aflito.
#
# - 2 🪽🪽: uma condição de impureza, culpa ou medo é removida da cena.
#
# - 3 🪽🪽🪽: o grupo recebe renovação espiritual em meio à crise.
#
# - 4+ 🪽🪽🪽🪽: a intercessão do sacerdote resulta em restauração ampla, como se a cena inteira fosse reorientada para a presença de Deus.

# %% [markdown]
# ### Testes de resultados dos dados

# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configurações iniciais dos dados
comum = ["⭐", "❌", "", "☀️", "+🟥", "+🟩"]
dificuldade = ["+⬜", "⚠️", "", "❌⚠️", "⛔"]
fe = ["🔵", "👉🏼", "🛡️", "🪽", "+⬜", "", ""]

def rolar_dado(tipo_dado):
    return random.choice(tipo_dado)

def realizar_rolagem(tipo_teste):
    """
    Realiza uma rolagem completa de dados para um determinado tipo de teste.
    Retorna o saldo líquido da rolagem.
    """
    dados_a_rolar = [comum] * tipo_teste
    resultados_brutos = []

    while dados_a_rolar:
        dado_atual = dados_a_rolar.pop(0)
        resultado = rolar_dado(dado_atual)
        resultados_brutos.append(resultado)

        if resultado == "+🟥":
            dados_a_rolar.append(dificuldade)
        elif resultado == "+🟩":
            dados_a_rolar.append(fe)
        elif resultado == "+⬜":
            dados_a_rolar.append(comum)

    resultado_liquido = 0
    for i in resultados_brutos:
        if i == "⭐" or i == "🛡️":
            resultado_liquido += 1
        elif i in ["❌", "❌⚠️"]:
            resultado_liquido -= 1
        elif i == "☀️":
            resultado_liquido += 2

    return resultado_liquido

# %%
# Configurações da simulação
quantidades = [100, 1000, 10000, 100000, 1000000]
tipos_teste = {2: "Desvantagem", 3: "Normal", 4: "Vantagem"}

resultados_gerais = []
taxas_sucesso = {nome: [] for nome in tipos_teste.values()}

print("Iniciando as simulações (isso pode levar de 10 a 20 segundos)...")

# Executando simulação
for q in quantidades:
    for tipo, nome in tipos_teste.items():
        sucessos = 0
        for _ in range(q):
            res = realizar_rolagem(tipo)
            # Armazena os dados para os boxplots
            resultados_gerais.append({'Quantidade': q, 'Teste': nome, 'Resultado Líquido': res})

            # Conta os sucessos para o gráfico de linhas
            if res > 0:
                sucessos += 1

        taxa = (sucessos / q) * 100
        taxas_sucesso[nome].append(taxa)

df_resultados = pd.DataFrame(resultados_gerais)
print("Simulação concluída com sucesso! Os dados estão prontos para os gráficos.")
# Out:
# Iniciando as simulações (isso pode levar de 10 a 20 segundos)...
# Simulação concluída com sucesso! Os dados estão prontos para os gráficos.

# %%
# Configurações visuais do Boxplot
plt.style.use('ggplot')
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

tipos = ["Desvantagem", "Normal", "Vantagem"]

for i, nome in enumerate(tipos):
    df_filtrado = df_resultados[df_resultados['Teste'] == nome]

    # CORREÇÃO APLICADA AQUI: hue='Quantidade' e legend=False adicionados
    sns.boxplot(data=df_filtrado, x='Quantidade', y='Resultado Líquido', hue='Quantidade',
                ax=axes[i], palette="viridis", legend=False)

    axes[i].set_title(f'Distribuição - Teste {nome}')
    axes[i].set_xlabel('Quantidade de Rolagens')

    # Coloca o rótulo do eixo Y apenas no primeiro gráfico
    if i == 0:
        axes[i].set_ylabel('Resultado Líquido')
    else:
        axes[i].set_ylabel('')

    # Formata os labels do eixo X (ex: 1.000, 10.000)
    labels = [f'{q:,}'.replace(',', '.') for q in quantidades]
    axes[i].set_xticks(range(len(quantidades)))
    axes[i].set_xticklabels(labels, rotation=45)

plt.tight_layout()
plt.show()

# %%
# Configurações visuais do Gráfico de Linhas
plt.figure(figsize=(10, 6))
cores = {'Desvantagem': '#e74c3c', 'Normal': '#3498db', 'Vantagem': '#2ecc71'}
tipos = ["Desvantagem", "Normal", "Vantagem"]

for nome in tipos:
    plt.plot(quantidades, taxas_sucesso[nome], marker='o', markersize=8,
             label=f'{nome} ({list(tipos_teste.keys())[tipos.index(nome)]} Dados)',
             color=cores[nome], linewidth=2.5)

# Aplica a escala logarítmica no eixo X
plt.xscale('log')

# Textos e rótulos
plt.title('Taxa de Sucesso (%) vs Quantidade de Rolagens', fontsize=16)
plt.xlabel('Quantidade de Rolagens (Escala Logarítmica)', fontsize=12)
plt.ylabel('Taxa de Sucesso (%)', fontsize=12)

# Ajusta a formatação dos números no eixo X para o padrão com pontos
plt.xticks(quantidades, [f'{q:,}'.replace(',', '.') for q in quantidades])

plt.legend(fontsize=12)
plt.grid(True, which="both", ls="--", alpha=0.7)

plt.show()

# %% [markdown]
# ## Regra prática para evitar confusão
# Se a dúvida for entre duas perícias, use esta lógica:
#
# É físico e direto? Luta.
#
# É físico prolongado? Trabalho ou Resistência.
#
# É sobreviver no ambiente? Sobrevivência.
#
# É notar algo? Percepção.
#
# É entender intenção? Intuição.
#
# É falar com alguém? Diplomacia.
#
# É comandar um grupo? Liderança.
#
# É coisa sagrada? Teologia.
#
# É lembrar fatos antigos? História.
#
# É fabricar ou arrumar? Ofício.
#
# Exemplo de cena
# O grupo chega a uma aldeia cananeia.
#
# O líder usa Diplomacia para pedir água.
#
# O sentinela usa Percepção para notar guardas escondidos.
#
# O batedor usa Furtividade para entrar na vila.
#
# O artesão usa Ofício para reparar uma roda quebrada.
#
# O profeta usa Teologia para interpretar um presságio.
#
# O guerreiro usa Luta se a negociação falhar.
#
# Posso transformar isso em uma tabela de referência rápida de uma página, ou já organizar as perícias em formato de ficha de personagem com exemplos de vantagem e desvantagem por tribo.

# %% [markdown]
# # (editar) Combate
# O sistema de combate de rápido, narrativo e narração de resultados.
#
# ## Iniciativa
#
# Se os jogadores estão cientes, todos jogadores rolam o teste de **Vontade**. Se forem surpreendidos, façam o teste de **Percepção**.
#
# Quem tiver maior resultado líquido, jogará primeiro.
#
# Se empatar, quem tiver mais símbolos de Direção ou Vantagem age primeiro.
#
# Se ainda empatar, o narrador decide com base na ficção.
#
# Uso narrativo
# Percepção para notar o perigo primeiro.
#
# Vontade para não hesitar sob ameaça.
#
# Ataque padrão
# No ataque, o jogador rola os 3 dados comuns.
#
# Resultado do ataque
# ★ = 1 acerto.
#
# ☀ = 2 acertos.
#
# ✖ = cancela 1 acerto.
#
# +✴️ = adiciona dado de dificuldade ao defensor ou à cena.
#
# +🆙 = pode gerar dado de Fé, se a cena permitir.
#
# Dano simples
# Eu sugiro que o dano seja a diferença entre:
#
# sucessos do atacante
#
# menos defesas, anulações e proteções
#
# Isso mantém o sistema fluido.
#
# Defesa no combate
# Aqui você pode usar duas opções, e eu acho que a melhor é permitir ambas conforme o tipo de defesa.
#
# 1. Defesa passiva
# O defensor não rola nada.
# O atacante só precisa superar a Defesa da posição do alvo.
#
# Boa para:
#
# manter ritmo rápido;
#
# inimigos comuns;
#
# cenas com muitos combatentes.
#
# 2. Defesa ativa
# O defensor rola um teste antagônico de:
#
# Acrobacia para esquivar;
#
# Resistência para firmar postura, bloquear ou aguentar o impacto;
#
# Luta se quiser aparar, conter ou lutar de perto.
#
# Boa para:
#
# chefes;
#
# duelos;
#
# momentos dramáticos.
#
# Testes antagônicos
# Eu faria o teste antagônico assim:
#
# Regra base
# Ambos rolam seus dados.
#
# Cada lado soma seus sucessos líquidos.
#
# Quem tiver mais sucessos vence.
#
# A diferença define a intensidade do efeito.
#
# Grau de vitória
# 1 sucesso de diferença: vitória leve.
#
# 2 sucessos de diferença: vitória clara.
#
# 3 sucessos de diferença: vitória decisiva.
#
# 4+ sucessos de diferença: vitória esmagadora.
#
# Antagonismo no combate
# Ataque vs Defesa
# Exemplo:
#
# Atacante rola 2 sucessos líquidos.
#
# Defensor rola 1 sucesso líquido em Acrobacia.
#
# Resultado final: 1 acerto.
#
# Se o defensor tiver:
#
# Proteção 🛡️, pode cancelar uma complicação, anulação ou parte do dano.
#
# Direção 👉🏼, pode reposicionar-se ou escolher melhor a defesa.
#
# Milagre raro 🪽, pode evitar uma consequência grave.
#
# O papel da dificuldade no combate
# Eu trataria o dado de dificuldade como o peso do combate.
#
# Quando adicionar dificuldade
# terreno ruim;
#
# chuva, lama, areia, noite;
#
# inimigos numerosos;
#
# exaustão;
#
# ferimentos prévios;
#
# armas inadequadas;
#
# escudo quebrado;
#
# hesitação emocional;
#
# perder 1 rodada.
#
# Efeitos possíveis
# reduzir sucessos;
#
# gerar complicações;
#
# criar desvantagem para a próxima ação;
#
# impor atraso ou abertura tática.
#
# Ferimentos
# Em vez de pontos de vida complexos, eu usaria 3 ou 4 níveis de ferimento.
#
# Exemplo simples
# Sem ferimento
#
# Ferido
#
# Gravemente ferido
#
# Caído
#
# Incapacitado
#
# Como aplicar
# Cada ataque bem-sucedido pode:
#
# causar 1 nível de ferimento;
#
# ou piorar o ferimento existente, se a diferença for grande.
#
# Uso dos símbolos
# Complicação pode causar corte, perda de arma, tropeço ou sangramento.
#
# Anulação cancela parte do golpe.
#
# Proteção reduz ferimento.
#
# Milagre raro pode impedir que um personagem caia.
#
# Combate como cena
# Uma boa forma de simplificar ainda mais é tratar o combate como cena em andamento, não como troca de números a cada golpe.
#
# Rodada
# Cada rodada um personagem escolhe uma ação:
#
# atacar;
#
# defender;
#
# correr;
#
# proteger aliado;
#
# usar liderança;
#
# buscar cobertura;
#
# invocar fé / agir com propósito.
#
# Efeito do sucesso
# sucesso simples: faz a ação.
#
# sucesso forte: faz com vantagem.
#
# complicação: faz, mas paga preço.
#
# anulação: falha.
#
# milagre raro: efeito especial ligado ao treinamento.
#
# Minha sugestão prática de combate
# Eu faria assim:
#
# Ataque
# 3 dados comuns.
#
# Defesa
# 2 dados se a defesa for ativa.
#
# 1 dado se o personagem estiver desprevenido.
#
# sem rolagem se for defesa passiva.
#
# Resultado
# sucessos líquidos do ataque - sucessos líquidos da defesa = resultado final.
#
# Interpretação
# 0 ou menos: não acerta ou é totalmente bloqueado.
#
# 1: arranha, pressiona ou ferimento leve.
#
# 2: acerto sólido.
#
# 3: acerto forte.
#
# 4+: golpe decisivo.
#
# Testes antagônicos fora do combate
# Esse mesmo modelo serve para:
#
# Diplomacia vs Intuição
#
# Furtividade vs Percepção
#
# Liderança vs Vontade
#
# História vs História
#
# Cura vs Resistência em situações de doença
#
# Teologia vs Vontade para resistir a influência espiritual
#
# Regra simples
# quem tiver mais sucessos líquidos vence;
#
# empate favorece quem tiver melhor posição narrativa;
#
# em caso de empate perfeito, surge uma complicação ou escolha difícil.
#
# Regras que eu evitaria
# Eu evitaria:
#
# bônus numéricos demais;
#
# defesa automática muito alta;
#
# muitos tipos de dano;
#
# tabelas longas de armas;
#
# subtração constante em toda rolagem.
#
# Seu sistema ganha muito mais se o combate for:
#
# rápido;
#
# simbólico;
#
# tenso;
#
# com custo narrativo real.
#
# Resumo da minha proposta
# Combate
# rolagem simbólica;
#
# ataque e defesa antagônicos;
#
# dificuldade gera custo;
#
# ferimentos em estágios;
#
# milagre raro como intervenção decisiva.
#
# Testes antagônicos
# cada lado rola seus dados;
#
# compara sucessos líquidos;
#
# diferença define intensidade;
#
# complicações e fé alteram a cena.
#
# Se quiser, eu posso transformar isso em uma regra formal de manual, já com texto pronto para o livro e uma seção específica de combate, defesa, ferimentos e testes antagônicos.

# %% [markdown]
# # Foco espiritual do jogo
# Como você quer minimizar a temática mágica para os jogadores, o jogo pode tratar o sobrenatural de forma mais reverente e rara. Em vez de “magias”, os personagens têm:
#
# atos de fé;
#
# orações respondidas;
#
# direção divina;
#
# consolo e encorajamento;
#
# proteção providencial;
#
# sabedoria concedida por Deus em momentos críticos.
#
# Isso mantém o cenário bíblico forte sem transformar os personagens em lançadores de feitiços. A sensação do jogo passa a ser: o personagem não controla o divino, ele depende do divino.
#
# Se quiser, eu posso transformar isso agora em um texto ainda mais “editorial”, com linguagem de livro mesmo, já no formato final de manual, incluindo títulos, subtítulos e redação uniforme para colar direto no documento.

# %% [markdown]
# #FICHA DE PERSONAGEM – RPG BÍBLICO D6
#
# Nome:
# Povo:
# Treinamento:
# História / Vocação:
#
# Atributos:
# FOR ___  AGI ___  VGR ___  INT ___  SAB ___  PRS ___
#
# Dados de Classe atuais: ___
#
# ATRIBUTOS
# FOR: ___   (vantagem em perícia: __________)
#
# AGI: ___   (vantagem em perícia: __________)
#
# VGR: ___   (vantagem em perícia: __________)
#
# INT: ___   (vantagem em perícia: __________)
#
# SAB: ___   (vantagem em perícia: __________)
#
# PRS: ___   (vantagem em perícia: __________)
#
# PERÍCIAS (marque com X as que tem vantagem)
#
# [ ] Luta        [ ] Trabalho     [ ] Arquearia
#
# [ ] Furtividade [ ] Acrobacia    [ ] Resistência
#
# [ ] Sobrevivência [ ] Cura       [ ] Teologia
#
# [ ] História    [ ] Ofício       [ ] Percepção
#
# [ ] Intuição    [ ] Vontade      [ ] Diplomacia
#
# [ ] Liderança   [ ] Performance
#
# VANTAGENS
# Por Atributo:
# -
#
# Por Povo:
# -
#
# Por Treinamento:
# -
#
# MARCAS DE FÉ / COMPROMISSO
# -
#
# DADOS DE CLASSE
# Treinamento:
# Faces do dado de classe:
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
#
# Quantidade atual de dados de classe: ___
#
# EQUIPAMENTO
# -
#
# ALIADOS E INIMIGOS
# Aliados:
# -
#
# Inimigos:
# -
#
# HISTÓRIA E VOCAÇÃO
# Origem:
# -
#
# Eventos marcantes:
# -
#
# Vocação / Chamado:
# -
#
# ANOTAÇÕES DE JOGO
# Ferimentos / Marcas:
# -
#
# Bênçãos / Direções:
# -
#
# Outras anotações:
# -

# %%
import random

class GeradorDeFicha:
    def __init__(self):
        # Listas extraídas das regras do sistema
        self.povos = [
            "Egípcios", "Filisteus", "Sidônios", "Cananeus", "Tribo de Israel",
            "Rúben", "Simeão", "Levi", "Judá", "Dã", "Naftali", "Gade", "Aser",
            "Issacar", "Zebulom", "Efraim", "Manassés", "Benjamim"
        ]

        self.treinamentos = [
            "Pastor nômade", "Artesão", "Guerreiro", "Guardião",
            "Profeta", "Levita/Sacerdote", "Conselheiro/Mensageiro"
        ]

        self.atributos = ["FOR", "AGI", "VGR", "INT", "SAB", "PRS"]

        self.pericias = {
            "Acrobacia": "AGI", "Arquearia": "AGI", "Cura": "SAB",
            "Diplomacia": "PRS", "Escalar": "FOR", "Furtividade": "AGI",
            "História": "INT", "Luta": "FOR", "Liderança": "PRS",
            "Ofício": "INT", "Percepção": "SAB", "Performance": "PRS",
            "Resistência": "VGR", "Sobrevivência": "VGR", "Teologia": "INT",
            "Trabalho": "FOR", "Tratamento": "VGR", "Vontade": "SAB"
        }

    def gerar_ficha(self, nome="Personagem Desconhecido"):
        ficha = {
            "Nome": nome,
            "Genealogia": "Desconhecida",
            "Povo": random.choice(self.povos),
            "Treinamento": random.choice(self.treinamentos),
            "Atributos": {},
            "Pericias": {}
        }

        # Distribuição de Atributos (exemplo: valores de 1 a 5)
        for attr in self.atributos:
            ficha["Atributos"][attr] = random.randint(1, 5)

        # Preenchimento de Perícias (Valor do atributo base + pontos de treinamento aleatórios)
        for pericia, attr_base in self.pericias.items():
            pontos_treinados = random.randint(0, 3)
            valor_total = ficha["Atributos"][attr_base] + pontos_treinados
            ficha["Pericias"][pericia] = f"{valor_total} (Base: {attr_base})"

        return ficha

    def exibir_ficha(self, ficha):
        print("="*40)
        print(f"NOME: {ficha['Nome']}")
        print(f"GENEALOGIA: {ficha['Genealogia']}")
        print(f"POVO: {ficha['Povo']}")
        print(f"TREINAMENTO: {ficha['Treinamento']}")
        print("="*40)

        print("\n--- ATRIBUTOS ---")
        for attr, valor in ficha['Atributos'].items():
            print(f"{attr}: {valor}")

        print("\n--- PERÍCIAS ---")
        # Ordenando alfabeticamente para facilitar a leitura
        for pericia in sorted(ficha['Pericias'].keys()):
            print(f"{pericia}: {ficha['Pericias'][pericia]}")
        print("="*40)

# Executando o gerador
if __name__ == "__main__":
    gerador = GeradorDeFicha()
    nova_ficha = gerador.gerar_ficha("Eliabe")
    gerador.exibir_ficha(nova_ficha)
# Out:
# ...
# NOME: Eliabe
# GENEALOGIA: Desconhecida
# POVO: Judá
# TREINAMENTO: Artesão
# ...
#
# --- ATRIBUTOS ---
# FOR: 4
# AGI: 1
# VGR: 3
# INT: 1
# SAB: 3
# PRS: 5
#
# --- PERÍCIAS ---
# Acrobacia: 3 (Base: AGI)
# Arquearia: 3 (Base: AGI)
# Cura: 6 (Base: SAB)
# Diplomacia: 6 (Base: PRS)
# Escalar: 6 (Base: FOR)
# Furtividade: 1 (Base: AGI)
# História: 2 (Base: INT)
# Liderança: 6 (Base: PRS)
# Luta: 7 (Base: FOR)
# Ofício: 2 (Base: INT)
# Percepção: 3 (Base: SAB)
# Performance: 6 (Base: PRS)
# Resistência: 6 (Base: VGR)
# Sobrevivência: 4 (Base: VGR)
# Teologia: 1 (Base: INT)
# Trabalho: 5 (Base: FOR)
# Tratamento: 6 (Base: VGR)
# Vontade: 4 (Base: SAB)
# ...
